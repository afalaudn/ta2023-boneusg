# %% [markdown]
# # Init Library

# %%
import os, glob
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from difflib import SequenceMatcher

from scipy import signal, fftpack
from scipy.fft import fft, fftfreq
from scipy.signal import butter, filtfilt

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, MinMaxScaler

from keras.models import Sequential, load_model
from keras.layers import LSTM, Dense, Activation, Dropout
from keras import utils
utils.to_categorical

from tensorflow.keras.utils import to_categorical

# %% [markdown]
# # Load directory

# %%
load = "C:/Users/Afif Alaudin/Documents/GitHub/ta2023-boneusg/Data 6 Juli - Fix/LTSM"
save = "C:/Users/Afif Alaudin/Documents/GitHub/ta2023-boneusg/Data 6 Juli - Fix/LTSM/Img"
proc_30 = 'C:/Users/Afif Alaudin/Documents/GitHub/ta2023-boneusg/Data 6 Juli - Fix/LTSM/Process/30%/*.csv'
proc_50 = 'C:/Users/Afif Alaudin/Documents/GitHub/ta2023-boneusg/Data 6 Juli - Fix/LTSM/Process/50%/*.csv'
proc_70 = 'C:/Users/Afif Alaudin/Documents/GitHub/ta2023-boneusg/Data 6 Juli - Fix/LTSM/Process/70%/*.csv'
proc_90 = 'C:/Users/Afif Alaudin/Documents/GitHub/ta2023-boneusg/Data 6 Juli - Fix/LTSM/Process/90%/*.csv'
combine = 'C:/Users/Afif Alaudin/Documents/GitHub/ta2023-boneusg/Data 6 Juli - Fix/LTSM/Process/Comb/*.csv'

# %% [markdown]
# # Parameter

# %%
lowcut = 2.0
highcut = 10.0
fs = 100.0
order = 5

# %% [markdown]
# # Apply Parameter

# %%
files_csv =[]
for root, dirs, files in os.walk(load):
    for file_name in files:
        if file_name.endswith(".csv"):
            file_load = os.path.join(root, file_name)
            files_csv.append(file_load)

# %%
i = 0

for file_csv in files_csv:
   
    df_uncut = pd.read_csv(file_csv)
    start_index = 1
    end_index = 1551
    df = df_uncut[start_index:end_index]
    var = df['X'].values
    data = df['Y'].values
     
    nyquist = 0.5 * fs
    low = lowcut / nyquist
    high = highcut / nyquist
    b, a = signal.butter(order, [low, high], btype='band')
    
    #Filter bandpass
    filtered_signal = signal.filtfilt(b, a, data)
    
    # Rectify signal
    rectified_signal = np.abs(filtered_signal)
    
    # One-sided FFT
    signal_fft = np.fft.fft(filtered_signal)
    signal_freq = np.fft.fftfreq(len(filtered_signal), 1/fs)
    n = len(filtered_signal)
    freq = signal_freq[0:int(n/2)]
    fft_amp = np.abs(signal_fft)[0:int(n/2)]/n*2
    
    # One-sided PSD
    psd = (1/(fs*n)) * np.square(np.abs(signal_fft[:n//2]))
    freq_psd = signal_freq[0:int(n/2)]
    psd_one_side = psd[0:int(n/2)]
    
    processed_csv_file = file_csv.replace(".csv", "_processed.csv")
    df.to_csv(processed_csv_file, index=False)
    
    # fig, axs = plt.subplots(2, 2, figsize=(10,10))

    # axs[0, 0].plot(var, filtered_signal)
    # axs[0, 0].set_title(file_csv)
    # axs[0, 0].set_xlabel('Time (us)')
    # axs[0, 0].set_ylabel('Amplitude (V)')

    # axs[0, 1].plot(var, rectified_signal)
    # axs[0, 1].set_title(file_csv)
    # axs[0, 1].set_xlabel('Time (us)')
    # axs[0, 1].set_ylabel('Amplitude (V)')

    # axs[1, 0].plot(freq, fft_amp)
    # axs[1, 0].set_title(file_csv)
    # axs[1, 0].set_xlabel('Frequency (MHz)')
    # axs[1, 0].set_ylabel('Amplitude Power/Frequency (dB/Hz)')

    # axs[1, 1].plot(freq_psd, psd_one_side)
    # axs[1, 1].set_title(file_csv)
    # axs[1, 1].set_xlabel('Frequency (MHz)')
    # axs[1, 1].set_ylabel('Power/Frequency (dB/Hz)')

    # save_img = file_csv+".png"
    # plt.savefig(save_img)

# %% [markdown]
# # Move PSD to New Folder

# %%
os.chdir(load)
if not os.path.exists(load+"Process"):
        os.makedirs(load+"Process")
        print("'data' folder created")
        
for root, dirs, files in os.walk(load):
        for filename in files:
            if filename.endswith("_processed.csv"):
                original_file = os.path.join(root, filename)                
                if not "Process/" in original_file:
                    print("Moved '",original_file," to ","./Process/"+filename)
                    os.rename(original_file, "./Process/"+filename)
# Out:
# Moved ' C:/Users/Afif Alaudin/Documents/GitHub/ta2023-boneusg/Data 6 Juli - Fix/LTSM\data_predict_predicted_processed.csv  to  ./Process/data_predict_predicted_processed.csv
# Moved ' C:/Users/Afif Alaudin/Documents/GitHub/ta2023-boneusg/Data 6 Juli - Fix/LTSM\30%\A301_processed.csv  to  ./Process/A301_processed.csv
# Moved ' C:/Users/Afif Alaudin/Documents/GitHub/ta2023-boneusg/Data 6 Juli - Fix/LTSM\30%\A302_processed.csv  to  ./Process/A302_processed.csv
# Moved ' C:/Users/Afif Alaudin/Documents/GitHub/ta2023-boneusg/Data 6 Juli - Fix/LTSM\30%\A303_processed.csv  to  ./Process/A303_processed.csv
# Moved ' C:/Users/Afif Alaudin/Documents/GitHub/ta2023-boneusg/Data 6 Juli - Fix/LTSM\30%\A304_processed.csv  to  ./Process/A304_processed.csv
# Moved ' C:/Users/Afif Alaudin/Documents/GitHub/ta2023-boneusg/Data 6 Juli - Fix/LTSM\30%\A305_processed.csv  to  ./Process/A305_processed.csv
# Moved ' C:/Users/Afif Alaudin/Documents/GitHub/ta2023-boneusg/Data 6 Juli - Fix/LTSM\30%\K301_processed.csv  to  ./Process/K301_processed.csv
# Moved ' C:/Users/Afif Alaudin/Documents/GitHub/ta2023-boneusg/Data 6 Juli - Fix/LTSM\30%\K302_processed.csv  to  ./Process/K302_processed.csv
# Moved ' C:/Users/Afif Alaudin/Documents/GitHub/ta2023-boneusg/Data 6 Juli - Fix/LTSM\30%\S301_processed.csv  to  ./Process/S301_processed.csv
# Moved ' C:/Users/Afif Alaudin/Documents/GitHub/ta2023-boneusg/Data 6 Juli - Fix/LTSM\30%\S302_processed.csv  to  ./Process/S302_processed.csv
# Moved ' C:/Users/Afif Alaudin/Documents/GitHub/ta2023-boneusg/Data 6 Juli - Fix/LTSM\30%\S303_processed.csv  to  ./Process/S303_processed.csv
# Moved ' C:/Users/Afif Alaudin/Documents/GitHub/ta2023-boneusg/Data 6 Juli - Fix/LTSM\30%\S304_processed.csv  to  ./Process/S304_processed.csv
# Moved ' C:/Users/Afif Alaudin/Documents/GitHub/ta2023-boneusg/Data 6 Juli - Fix/LTSM\30%\S305_processed.csv  to  ./Process/S305_processed.csv
# Moved ' C:/Users/Afif Alaudin/Documents/GitHub/ta2023-boneusg/Data 6 Juli - Fix/LTSM\50%\A501_processed.csv  to  ./Process/A501_processed.csv
# Moved ' C:/Users/Afif Alaudin/Documents/GitHub/ta2023-boneusg/Data 6 Juli - Fix/LTSM\50%\A502_processed.csv  to  ./Process/A502_processed.csv
# Moved ' C:/Users/Afif Alaudin/Documents/GitHub/ta2023-boneusg/Data 6 Juli - Fix/LTSM\50%\A503_processed.csv  to  ./Process/A503_processed.csv
# Moved ' C:/Users/Afif Alaudin/Documents/GitHub/ta2023-boneusg/Data 6 Juli - Fix/LTSM\50%\A504_processed.csv  to  ./Process/A504_processed.csv
# Moved ' C:/Users/Afif Alaudin/Documents/GitHub/ta2023-boneusg/Data 6 Juli - Fix/LTSM\50%\A505_processed.csv  to  ./Process/A505_processed.csv
# Moved ' C:/Users/Afif Alaudin/Documents/GitHub/ta2023-boneusg/Data 6 Juli - Fix/LTSM\50%\K501_processed.csv  to  ./Process/K501_processed.csv
# Moved ' C:/Users/Afif Alaudin/Documents/GitHub/ta2023-boneusg/Data 6 Juli - Fix/LTSM\50%\K502_processed.csv  to  ./Process/K502_processed.csv
# Moved ' C:/Users/Afif Alaudin/Documents/GitHub/ta2023-boneusg/Data 6 Juli - Fix/LTSM\50%\S501_processed.csv  to  ./Process/S501_processed.csv
# Moved ' C:/Users/Afif Alaudin/Documents/GitHub/ta2023-boneusg/Data 6 Juli - Fix/LTSM\50%\S502_processed.csv  to  ./Process/S502_processed.csv
# Moved ' C:/Users/Afif Alaudin/Documents/GitHub/ta2023-boneusg/Data 6 Juli - Fix/LTSM\50%\S503_processed.csv  to  ./Process/S503_processed.csv
# Moved ' C:/Users/Afif Alaudin/Documents/GitHub/ta2023-boneusg/Data 6 Juli - Fix/LTSM\50%\S504_processed.csv  to  ./Process/S504_processed.csv
# Moved ' C:/Users/Afif Alaudin/Documents/GitHub/ta2023-boneusg/Data 6 Juli - Fix/LTSM\50%\S505_processed.csv  to  ./Process/S505_processed.csv
# Moved ' C:/Users/Afif Alaudin/Documents/GitHub/ta2023-boneusg/Data 6 Juli - Fix/LTSM\70%\A701_processed.csv  to  ./Process/A701_processed.csv
# Moved ' C:/Users/Afif Alaudin/Documents/GitHub/ta2023-boneusg/Data 6 Juli - Fix/LTSM\70%\A702_processed.csv  to  ./Process/A702_processed.csv
# Moved ' C:/Users/Afif Alaudin/Documents/GitHub/ta2023-boneusg/Data 6 Juli - Fix/LTSM\70%\A703_processed.csv  to  ./Process/A703_processed.csv
# Moved ' C:/Users/Afif Alaudin/Documents/GitHub/ta2023-boneusg/Data 6 Juli - Fix/LTSM\70%\A704_processed.csv  to  ./Process/A704_processed.csv
# Moved ' C:/Users/Afif Alaudin/Documents/GitHub/ta2023-boneusg/Data 6 Juli - Fix/LTSM\70%\A705_processed.csv  to  ./Process/A705_processed.csv
# Moved ' C:/Users/Afif Alaudin/Documents/GitHub/ta2023-boneusg/Data 6 Juli - Fix/LTSM\70%\K701_processed.csv  to  ./Process/K701_processed.csv
# Moved ' C:/Users/Afif Alaudin/Documents/GitHub/ta2023-boneusg/Data 6 Juli - Fix/LTSM\70%\K702_processed.csv  to  ./Process/K702_processed.csv
# Moved ' C:/Users/Afif Alaudin/Documents/GitHub/ta2023-boneusg/Data 6 Juli - Fix/LTSM\70%\S701_processed.csv  to  ./Process/S701_processed.csv
# Moved ' C:/Users/Afif Alaudin/Documents/GitHub/ta2023-boneusg/Data 6 Juli - Fix/LTSM\70%\S702_processed.csv  to  ./Process/S702_processed.csv
# Moved ' C:/Users/Afif Alaudin/Documents/GitHub/ta2023-boneusg/Data 6 Juli - Fix/LTSM\70%\S703_processed.csv  to  ./Process/S703_processed.csv
# Moved ' C:/Users/Afif Alaudin/Documents/GitHub/ta2023-boneusg/Data 6 Juli - Fix/LTSM\70%\S704_processed.csv  to  ./Process/S704_processed.csv
# Moved ' C:/Users/Afif Alaudin/Documents/GitHub/ta2023-boneusg/Data 6 Juli - Fix/LTSM\70%\S705_processed.csv  to  ./Process/S705_processed.csv
# Moved ' C:/Users/Afif Alaudin/Documents/GitHub/ta2023-boneusg/Data 6 Juli - Fix/LTSM\90%\A901_processed.csv  to  ./Process/A901_processed.csv
# Moved ' C:/Users/Afif Alaudin/Documents/GitHub/ta2023-boneusg/Data 6 Juli - Fix/LTSM\90%\A902_processed.csv  to  ./Process/A902_processed.csv
# Moved ' C:/Users/Afif Alaudin/Documents/GitHub/ta2023-boneusg/Data 6 Juli - Fix/LTSM\90%\A903_processed.csv  to  ./Process/A903_processed.csv
# Moved ' C:/Users/Afif Alaudin/Documents/GitHub/ta2023-boneusg/Data 6 Juli - Fix/LTSM\90%\A904_processed.csv  to  ./Process/A904_processed.csv
# Moved ' C:/Users/Afif Alaudin/Documents/GitHub/ta2023-boneusg/Data 6 Juli - Fix/LTSM\90%\A905_processed.csv  to  ./Process/A905_processed.csv
# Moved ' C:/Users/Afif Alaudin/Documents/GitHub/ta2023-boneusg/Data 6 Juli - Fix/LTSM\90%\K901_processed.csv  to  ./Process/K901_processed.csv
# Moved ' C:/Users/Afif Alaudin/Documents/GitHub/ta2023-boneusg/Data 6 Juli - Fix/LTSM\90%\K902_processed.csv  to  ./Process/K902_processed.csv
# Moved ' C:/Users/Afif Alaudin/Documents/GitHub/ta2023-boneusg/Data 6 Juli - Fix/LTSM\90%\S901_processed.csv  to  ./Process/S901_processed.csv
# Moved ' C:/Users/Afif Alaudin/Documents/GitHub/ta2023-boneusg/Data 6 Juli - Fix/LTSM\90%\S902_processed.csv  to  ./Process/S902_processed.csv
# Moved ' C:/Users/Afif Alaudin/Documents/GitHub/ta2023-boneusg/Data 6 Juli - Fix/LTSM\90%\S903_processed.csv  to  ./Process/S903_processed.csv
# Moved ' C:/Users/Afif Alaudin/Documents/GitHub/ta2023-boneusg/Data 6 Juli - Fix/LTSM\90%\S904_processed.csv  to  ./Process/S904_processed.csv
# Moved ' C:/Users/Afif Alaudin/Documents/GitHub/ta2023-boneusg/Data 6 Juli - Fix/LTSM\90%\S905_processed.csv  to  ./Process/S905_processed.csv
# Moved ' C:/Users/Afif Alaudin/Documents/GitHub/ta2023-boneusg/Data 6 Juli - Fix/LTSM\Process\A301_processed.csv  to  ./Process/A301_processed.csv
# Moved ' C:/Users/Afif Alaudin/Documents/GitHub/ta2023-boneusg/Data 6 Juli - Fix/LTSM\Process\A302_processed.csv  to  ./Process/A302_processed.csv
# Moved ' C:/Users/Afif Alaudin/Documents/GitHub/ta2023-boneusg/Data 6 Juli - Fix/LTSM\Process\A303_processed.csv  to  ./Process/A303_processed.csv
# Moved ' C:/Users/Afif Alaudin/Documents/GitHub/ta2023-boneusg/Data 6 Juli - Fix/LTSM\Process\A304_processed.csv  to  ./Process/A304_processed.csv
# Moved ' C:/Users/Afif Alaudin/Documents/GitHub/ta2023-boneusg/Data 6 Juli - Fix/LTSM\Process\A305_processed.csv  to  ./Process/A305_processed.csv
# Moved ' C:/Users/Afif Alaudin/Documents/GitHub/ta2023-boneusg/Data 6 Juli - Fix/LTSM\Process\A501_processed.csv  to  ./Process/A501_processed.csv
# Moved ' C:/Users/Afif Alaudin/Documents/GitHub/ta2023-boneusg/Data 6 Juli - Fix/LTSM\Process\A502_processed.csv  to  ./Process/A502_processed.csv
# Moved ' C:/Users/Afif Alaudin/Documents/GitHub/ta2023-boneusg/Data 6 Juli - Fix/LTSM\Process\A503_processed.csv  to  ./Process/A503_processed.csv
# Moved ' C:/Users/Afif Alaudin/Documents/GitHub/ta2023-boneusg/Data 6 Juli - Fix/LTSM\Process\A504_processed.csv  to  ./Process/A504_processed.csv
# Moved ' C:/Users/Afif Alaudin/Documents/GitHub/ta2023-boneusg/Data 6 Juli - Fix/LTSM\Process\A505_processed.csv  to  ./Process/A505_processed.csv
# Moved ' C:/Users/Afif Alaudin/Documents/GitHub/ta2023-boneusg/Data 6 Juli - Fix/LTSM\Process\A701_processed.csv  to  ./Process/A701_processed.csv
# Moved ' C:/Users/Afif Alaudin/Documents/GitHub/ta2023-boneusg/Data 6 Juli - Fix/LTSM\Process\A702_processed.csv  to  ./Process/A702_processed.csv
# Moved ' C:/Users/Afif Alaudin/Documents/GitHub/ta2023-boneusg/Data 6 Juli - Fix/LTSM\Process\A703_processed.csv  to  ./Process/A703_processed.csv
# Moved ' C:/Users/Afif Alaudin/Documents/GitHub/ta2023-boneusg/Data 6 Juli - Fix/LTSM\Process\A704_processed.csv  to  ./Process/A704_processed.csv
# Moved ' C:/Users/Afif Alaudin/Documents/GitHub/ta2023-boneusg/Data 6 Juli - Fix/LTSM\Process\A705_processed.csv  to  ./Process/A705_processed.csv
# Moved ' C:/Users/Afif Alaudin/Documents/GitHub/ta2023-boneusg/Data 6 Juli - Fix/LTSM\Process\A901_processed.csv  to  ./Process/A901_processed.csv
# Moved ' C:/Users/Afif Alaudin/Documents/GitHub/ta2023-boneusg/Data 6 Juli - Fix/LTSM\Process\A902_processed.csv  to  ./Process/A902_processed.csv
# Moved ' C:/Users/Afif Alaudin/Documents/GitHub/ta2023-boneusg/Data 6 Juli - Fix/LTSM\Process\A903_processed.csv  to  ./Process/A903_processed.csv
# Moved ' C:/Users/Afif Alaudin/Documents/GitHub/ta2023-boneusg/Data 6 Juli - Fix/LTSM\Process\A904_processed.csv  to  ./Process/A904_processed.csv
# Moved ' C:/Users/Afif Alaudin/Documents/GitHub/ta2023-boneusg/Data 6 Juli - Fix/LTSM\Process\A905_processed.csv  to  ./Process/A905_processed.csv
# Moved ' C:/Users/Afif Alaudin/Documents/GitHub/ta2023-boneusg/Data 6 Juli - Fix/LTSM\Process\data_predict_predicted_processed.csv  to  ./Process/data_predict_predicted_processed.csv
# Moved ' C:/Users/Afif Alaudin/Documents/GitHub/ta2023-boneusg/Data 6 Juli - Fix/LTSM\Process\K301_processed.csv  to  ./Process/K301_processed.csv
# Moved ' C:/Users/Afif Alaudin/Documents/GitHub/ta2023-boneusg/Data 6 Juli - Fix/LTSM\Process\K302_processed.csv  to  ./Process/K302_processed.csv
# Moved ' C:/Users/Afif Alaudin/Documents/GitHub/ta2023-boneusg/Data 6 Juli - Fix/LTSM\Process\K501_processed.csv  to  ./Process/K501_processed.csv
# Moved ' C:/Users/Afif Alaudin/Documents/GitHub/ta2023-boneusg/Data 6 Juli - Fix/LTSM\Process\K502_processed.csv  to  ./Process/K502_processed.csv
# Moved ' C:/Users/Afif Alaudin/Documents/GitHub/ta2023-boneusg/Data 6 Juli - Fix/LTSM\Process\K701_processed.csv  to  ./Process/K701_processed.csv
# Moved ' C:/Users/Afif Alaudin/Documents/GitHub/ta2023-boneusg/Data 6 Juli - Fix/LTSM\Process\K702_processed.csv  to  ./Process/K702_processed.csv
# Moved ' C:/Users/Afif Alaudin/Documents/GitHub/ta2023-boneusg/Data 6 Juli - Fix/LTSM\Process\K901_processed.csv  to  ./Process/K901_processed.csv
# Moved ' C:/Users/Afif Alaudin/Documents/GitHub/ta2023-boneusg/Data 6 Juli - Fix/LTSM\Process\K902_processed.csv  to  ./Process/K902_processed.csv
# Moved ' C:/Users/Afif Alaudin/Documents/GitHub/ta2023-boneusg/Data 6 Juli - Fix/LTSM\Process\S301_processed.csv  to  ./Process/S301_processed.csv
# Moved ' C:/Users/Afif Alaudin/Documents/GitHub/ta2023-boneusg/Data 6 Juli - Fix/LTSM\Process\S302_processed.csv  to  ./Process/S302_processed.csv
# Moved ' C:/Users/Afif Alaudin/Documents/GitHub/ta2023-boneusg/Data 6 Juli - Fix/LTSM\Process\S303_processed.csv  to  ./Process/S303_processed.csv
# Moved ' C:/Users/Afif Alaudin/Documents/GitHub/ta2023-boneusg/Data 6 Juli - Fix/LTSM\Process\S304_processed.csv  to  ./Process/S304_processed.csv
# Moved ' C:/Users/Afif Alaudin/Documents/GitHub/ta2023-boneusg/Data 6 Juli - Fix/LTSM\Process\S305_processed.csv  to  ./Process/S305_processed.csv
# Moved ' C:/Users/Afif Alaudin/Documents/GitHub/ta2023-boneusg/Data 6 Juli - Fix/LTSM\Process\S501_processed.csv  to  ./Process/S501_processed.csv
# Moved ' C:/Users/Afif Alaudin/Documents/GitHub/ta2023-boneusg/Data 6 Juli - Fix/LTSM\Process\S502_processed.csv  to  ./Process/S502_processed.csv
# Moved ' C:/Users/Afif Alaudin/Documents/GitHub/ta2023-boneusg/Data 6 Juli - Fix/LTSM\Process\S503_processed.csv  to  ./Process/S503_processed.csv
# Moved ' C:/Users/Afif Alaudin/Documents/GitHub/ta2023-boneusg/Data 6 Juli - Fix/LTSM\Process\S504_processed.csv  to  ./Process/S504_processed.csv
# Moved ' C:/Users/Afif Alaudin/Documents/GitHub/ta2023-boneusg/Data 6 Juli - Fix/LTSM\Process\S505_processed.csv  to  ./Process/S505_processed.csv
# Moved ' C:/Users/Afif Alaudin/Documents/GitHub/ta2023-boneusg/Data 6 Juli - Fix/LTSM\Process\S701_processed.csv  to  ./Process/S701_processed.csv
# Moved ' C:/Users/Afif Alaudin/Documents/GitHub/ta2023-boneusg/Data 6 Juli - Fix/LTSM\Process\S702_processed.csv  to  ./Process/S702_processed.csv
# Moved ' C:/Users/Afif Alaudin/Documents/GitHub/ta2023-boneusg/Data 6 Juli - Fix/LTSM\Process\S703_processed.csv  to  ./Process/S703_processed.csv
# Moved ' C:/Users/Afif Alaudin/Documents/GitHub/ta2023-boneusg/Data 6 Juli - Fix/LTSM\Process\S704_processed.csv  to  ./Process/S704_processed.csv
# Moved ' C:/Users/Afif Alaudin/Documents/GitHub/ta2023-boneusg/Data 6 Juli - Fix/LTSM\Process\S705_processed.csv  to  ./Process/S705_processed.csv
# Moved ' C:/Users/Afif Alaudin/Documents/GitHub/ta2023-boneusg/Data 6 Juli - Fix/LTSM\Process\S901_processed.csv  to  ./Process/S901_processed.csv
# Moved ' C:/Users/Afif Alaudin/Documents/GitHub/ta2023-boneusg/Data 6 Juli - Fix/LTSM\Process\S902_processed.csv  to  ./Process/S902_processed.csv
# Moved ' C:/Users/Afif Alaudin/Documents/GitHub/ta2023-boneusg/Data 6 Juli - Fix/LTSM\Process\S903_processed.csv  to  ./Process/S903_processed.csv
# Moved ' C:/Users/Afif Alaudin/Documents/GitHub/ta2023-boneusg/Data 6 Juli - Fix/LTSM\Process\S904_processed.csv  to  ./Process/S904_processed.csv
# Moved ' C:/Users/Afif Alaudin/Documents/GitHub/ta2023-boneusg/Data 6 Juli - Fix/LTSM\Process\S905_processed.csv  to  ./Process/S905_processed.csv

# %% [markdown]
# # Gabungkan Dataset menjadi satu

# %%
# Menggunakan glob untuk mendapatkan daftar file CSV
csv_files = glob.glob(proc_30)

# Membuat list kosong untuk menyimpan DataFrame dari setiap file CSV
dataframes = []

# Menggabungkan semua file CSV menjadi satu DataFrame
for file in csv_files:
    df = pd.read_csv(file)
    dataframes.append(df)

# Menggabungkan DataFrame dalam list menjadi satu DataFrame utama
combined_df = pd.concat(dataframes, ignore_index=True)

combined_df.to_csv('C:/Users/Afif Alaudin/Documents/GitHub/ta2023-boneusg/Data 6 Juli - Fix/LTSM/Process/Comb/1.csv', index=True)
# combined_df.to_csv('E:/Sekolah/Telkom/TA/LTSM/Process/Comb/1.csv', index=False)

# %%
# Menggunakan glob untuk mendapatkan daftar file CSV
csv_files = glob.glob(proc_50)

# Membuat list kosong untuk menyimpan DataFrame dari setiap file CSV
dataframes = []

# Menggabungkan semua file CSV menjadi satu DataFrame
for file in csv_files:
    df = pd.read_csv(file)
    dataframes.append(df)

# Menggabungkan DataFrame dalam list menjadi satu DataFrame utama
combined_df = pd.concat(dataframes, ignore_index=True)

combined_df.to_csv('C:/Users/Afif Alaudin/Documents/GitHub/ta2023-boneusg/Data 6 Juli - Fix/LTSM/Process/Comb/2.csv', index=True)

# %%
# Menggunakan glob untuk mendapatkan daftar file CSV
csv_files = glob.glob(proc_70)

# Membuat list kosong untuk menyimpan DataFrame dari setiap file CSV
dataframes = []

# Menggabungkan semua file CSV menjadi satu DataFrame
for file in csv_files:
    df = pd.read_csv(file)
    dataframes.append(df)

# Menggabungkan DataFrame dalam list menjadi satu DataFrame utama
combined_df = pd.concat(dataframes, ignore_index=True)

combined_df.to_csv('C:/Users/Afif Alaudin/Documents/GitHub/ta2023-boneusg/Data 6 Juli - Fix/LTSM/Process/Comb/3.csv', index=True)

# %%
# Menggunakan glob untuk mendapatkan daftar file CSV
csv_files = glob.glob(proc_90)

# Membuat list kosong untuk menyimpan DataFrame dari setiap file CSV
dataframes = []

# Menggabungkan semua file CSV menjadi satu DataFrame
for file in csv_files:
    df = pd.read_csv(file)
    dataframes.append(df)

# Menggabungkan DataFrame dalam list menjadi satu DataFrame utama
combined_df = pd.concat(dataframes, ignore_index=True)

combined_df.to_csv('C:/Users/Afif Alaudin/Documents/GitHub/ta2023-boneusg/Data 6 Juli - Fix/LTSM/Process/Comb/4.csv', index=True)

# %%
merge = 'C:/Users/Afif Alaudin/Documents/GitHub/ta2023-boneusg/Data 6 Juli - Fix/LTSM/Process/Comb/All.csv'

# Menggunakan glob untuk mendapatkan daftar file CSV
csv_files = glob.glob(combine)

# Membuat list kosong untuk menyimpan DataFrame dari setiap file CSV
dataframes = []

# Menggabungkan semua file CSV menjadi satu DataFrame
for i, file in enumerate(csv_files):
    df = pd.read_csv(file)
    df['label'] = f'label_{i+1}'
    dataframes.append(df)
# Menggabungkan DataFrame dalam list menjadi satu DataFrame utama
combined_df = pd.concat(dataframes, ignore_index=True)

# Menampilkan hasil gabungan
print(combined_df)

combined_df.to_csv(merge, index=False)
# Out:
#        Unnamed: 0          X         Y    label
# 0               0   5.015625 -0.035156  label_1
# 1               1   5.031250 -0.039062  label_1
# 2               2   5.046875 -0.007812  label_1
# 3               3   5.062500  0.117188  label_1
# 4               4   5.078125 -0.339844  label_1
# ...           ...        ...       ...      ...
# 74395       20145  29.156250  0.031250  label_4
# 74396       20146  29.171875  0.039062  label_4
# 74397       20147  29.187500  0.035156  label_4
# 74398       20148  29.203125  0.035156  label_4
# 74399       20149  29.218750  0.031250  label_4
#
# [74400 rows x 4 columns]

# %% [markdown]
# # Rename Label

# %%
data_df = pd.read_csv(merge)

label_mapping = {
    'label_1': 'Density 30%',
    'label_2': 'Density 50%',
    'label_3': 'Density 70%',
    'label_4': 'Density 90%'
}

data_df['label'] = data_df['label'].map(label_mapping)
data_df.to_csv(merge, index=False)

# %% [markdown]
# # Train Dataset

# %%
# Membaca dataset utama untuk pelatihan
data_df = pd.read_csv(merge)
X = data_df.iloc[:, :-1].values
y = data_df.iloc[:, -1].values

# %%
# Menggunakan LabelEncoder untuk mengubah label menjadi nilai numerik
label_encoder = LabelEncoder()
y_encoded = label_encoder.fit_transform(y)
y_encoded_categorical = utils.to_categorical(y_encoded)
print(y_encoded_categorical.shape)
# Out:
# (74400, 4)

# %%
# Membagi dataset menjadi data pelatihan dan data validasi
X_train, X_test, y_train, y_test = train_test_split(X, y_encoded_categorical, test_size=0.2, random_state=42)

X_train = X_train.reshape((X_train.shape[0], X_train.shape[1], 1))
X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 1))

# %% [markdown]
# ## Metode LSTM

# %%
# Membangun model LSTM
model = Sequential()
model.add(LSTM(64, input_shape=(X_train.shape[1], X_train.shape[2])))
model.add(Dense(y_encoded_categorical.shape[1], activation='softmax'))
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
# Melatih model dengan dataset utama
history = model.fit(X_train, y_train, epochs=1000, batch_size=64, validation_data=(X_test, y_test))
# Out:
# Epoch 1/1000
# 930/930 [==============================] - 12s 7ms/step - loss: 1.3865 - accuracy: 0.2642 - val_loss: 1.3851 - val_accuracy: 0.2710
# Epoch 2/1000
# 930/930 [==============================] - 5s 6ms/step - loss: 1.3823 - accuracy: 0.2690 - val_loss: 1.3832 - val_accuracy: 0.2500
# Epoch 3/1000
# 930/930 [==============================] - 5s 5ms/step - loss: 1.3703 - accuracy: 0.2960 - val_loss: 1.3598 - val_accuracy: 0.3966
# Epoch 4/1000
# 930/930 [==============================] - 5s 5ms/step - loss: 1.3398 - accuracy: 0.3528 - val_loss: 1.3121 - val_accuracy: 0.3733
# Epoch 5/1000
# 930/930 [==============================] - 5s 6ms/step - loss: 1.2823 - accuracy: 0.3855 - val_loss: 1.2462 - val_accuracy: 0.3781
# Epoch 6/1000
# 930/930 [==============================] - 5s 5ms/step - loss: 1.2275 - accuracy: 0.3983 - val_loss: 1.2048 - val_accuracy: 0.4108
# Epoch 7/1000
# 930/930 [==============================] - 5s 5ms/step - loss: 1.1914 - accuracy: 0.4130 - val_loss: 1.1779 - val_accuracy: 0.4321
# Epoch 8/1000
# 930/930 [==============================] - 5s 6ms/step - loss: 1.1710 - accuracy: 0.4188 - val_loss: 1.1614 - val_accuracy: 0.4223
# Epoch 9/1000
# 930/930 [==============================] - 5s 5ms/step - loss: 1.1599 - accuracy: 0.4227 - val_loss: 1.1537 - val_accuracy: 0.4214
# Epoch 10/1000
# 930/930 [==============================] - 5s 5ms/step - loss: 1.1523 - accuracy: 0.4229 - val_loss: 1.1472 - val_accuracy: 0.4136
# Epoch 11/1000
# 930/930 [==============================] - 5s 5ms/step - loss: 1.1466 - accuracy: 0.4254 - val_loss: 1.1424 - val_accuracy: 0.4173
# Epoch 12/1000
# 930/930 [==============================] - 5s 6ms/step - loss: 1.1433 - accuracy: 0.4291 - val_loss: 1.1403 - val_accuracy: 0.4304
# Epoch 13/1000
# 930/930 [==============================] - 5s 5ms/step - loss: 1.1405 - accuracy: 0.4299 - val_loss: 1.1400 - val_accuracy: 0.4178
# Epoch 14/1000
# 930/930 [==============================] - 5s 6ms/step - loss: 1.1394 - accuracy: 0.4274 - val_loss: 1.1396 - val_accuracy: 0.4415
# Epoch 15/1000
# 930/930 [==============================] - 5s 5ms/step - loss: 1.1376 - accuracy: 0.4331 - val_loss: 1.1395 - val_accuracy: 0.4185
# Epoch 16/1000
# 930/930 [==============================] - 5s 5ms/step - loss: 1.1363 - accuracy: 0.4312 - val_loss: 1.1316 - val_accuracy: 0.4454
# Epoch 17/1000
# 930/930 [==============================] - 5s 6ms/step - loss: 1.1354 - accuracy: 0.4342 - val_loss: 1.1360 - val_accuracy: 0.4260
# Epoch 18/1000
# 930/930 [==============================] - 5s 5ms/step - loss: 1.1340 - accuracy: 0.4347 - val_loss: 1.1348 - val_accuracy: 0.4384
# Epoch 19/1000
# 930/930 [==============================] - 5s 5ms/step - loss: 1.1338 - accuracy: 0.4363 - val_loss: 1.1300 - val_accuracy: 0.4415
# Epoch 20/1000
# 930/930 [==============================] - 5s 6ms/step - loss: 1.1326 - accuracy: 0.4389 - val_loss: 1.1294 - val_accuracy: 0.4262
# Epoch 21/1000
# 930/930 [==============================] - 5s 5ms/step - loss: 1.1306 - accuracy: 0.4373 - val_loss: 1.1284 - val_accuracy: 0.4367
# Epoch 22/1000
# 930/930 [==============================] - 5s 6ms/step - loss: 1.1308 - accuracy: 0.4397 - val_loss: 1.1276 - val_accuracy: 0.4273
# Epoch 23/1000
# 930/930 [==============================] - 5s 5ms/step - loss: 1.1288 - accuracy: 0.4374 - val_loss: 1.1296 - val_accuracy: 0.4263
# Epoch 24/1000
# 930/930 [==============================] - 5s 6ms/step - loss: 1.1288 - accuracy: 0.4387 - val_loss: 1.1271 - val_accuracy: 0.4538
# Epoch 25/1000
# 930/930 [==============================] - 5s 6ms/step - loss: 1.1295 - accuracy: 0.4387 - val_loss: 1.1285 - val_accuracy: 0.4225
# Epoch 26/1000
# 930/930 [==============================] - 5s 5ms/step - loss: 1.1281 - accuracy: 0.4401 - val_loss: 1.1258 - val_accuracy: 0.4474
# Epoch 27/1000
# 930/930 [==============================] - 5s 5ms/step - loss: 1.1275 - accuracy: 0.4398 - val_loss: 1.1276 - val_accuracy: 0.4304
# Epoch 28/1000
# 930/930 [==============================] - 5s 6ms/step - loss: 1.1269 - accuracy: 0.4432 - val_loss: 1.1269 - val_accuracy: 0.4260
# Epoch 29/1000
# 930/930 [==============================] - 5s 5ms/step - loss: 1.1256 - accuracy: 0.4440 - val_loss: 1.1248 - val_accuracy: 0.4468
# Epoch 30/1000
# 930/930 [==============================] - 5s 5ms/step - loss: 1.1256 - accuracy: 0.4425 - val_loss: 1.1288 - val_accuracy: 0.4508
# Epoch 31/1000
# 930/930 [==============================] - 5s 6ms/step - loss: 1.1253 - accuracy: 0.4458 - val_loss: 1.1230 - val_accuracy: 0.4373
# Epoch 32/1000
# 930/930 [==============================] - 5s 5ms/step - loss: 1.1249 - accuracy: 0.4450 - val_loss: 1.1252 - val_accuracy: 0.4538
# Epoch 33/1000
# 930/930 [==============================] - 5s 6ms/step - loss: 1.1238 - accuracy: 0.4475 - val_loss: 1.1265 - val_accuracy: 0.4452
# Epoch 34/1000
# 930/930 [==============================] - 5s 6ms/step - loss: 1.1233 - accuracy: 0.4460 - val_loss: 1.1222 - val_accuracy: 0.4528
# Epoch 35/1000
# 930/930 [==============================] - 5s 6ms/step - loss: 1.1226 - accuracy: 0.4484 - val_loss: 1.1216 - val_accuracy: 0.4416
# Epoch 36/1000
# 930/930 [==============================] - 5s 5ms/step - loss: 1.1221 - accuracy: 0.4485 - val_loss: 1.1236 - val_accuracy: 0.4588
# Epoch 37/1000
# 930/930 [==============================] - 5s 5ms/step - loss: 1.1223 - accuracy: 0.4489 - val_loss: 1.1231 - val_accuracy: 0.4372
# Epoch 38/1000
# 930/930 [==============================] - 5s 6ms/step - loss: 1.1207 - accuracy: 0.4504 - val_loss: 1.1236 - val_accuracy: 0.4421
# Epoch 39/1000
# 930/930 [==============================] - 5s 5ms/step - loss: 1.1209 - accuracy: 0.4486 - val_loss: 1.1246 - val_accuracy: 0.4361
# Epoch 40/1000
# 930/930 [==============================] - 5s 6ms/step - loss: 1.1202 - accuracy: 0.4508 - val_loss: 1.1221 - val_accuracy: 0.4478
# Epoch 41/1000
# 930/930 [==============================] - 5s 5ms/step - loss: 1.1202 - accuracy: 0.4494 - val_loss: 1.1226 - val_accuracy: 0.4473
# Epoch 42/1000
# 930/930 [==============================] - 5s 5ms/step - loss: 1.1197 - accuracy: 0.4522 - val_loss: 1.1192 - val_accuracy: 0.4528
# Epoch 43/1000
# 930/930 [==============================] - 5s 6ms/step - loss: 1.1190 - accuracy: 0.4514 - val_loss: 1.1203 - val_accuracy: 0.4522
# Epoch 44/1000
# 930/930 [==============================] - 5s 5ms/step - loss: 1.1186 - accuracy: 0.4514 - val_loss: 1.1197 - val_accuracy: 0.4483
# Epoch 45/1000
# 930/930 [==============================] - 5s 5ms/step - loss: 1.1185 - accuracy: 0.4526 - val_loss: 1.1196 - val_accuracy: 0.4483
# Epoch 46/1000
# 930/930 [==============================] - 5s 6ms/step - loss: 1.1176 - accuracy: 0.4534 - val_loss: 1.1221 - val_accuracy: 0.4390
# Epoch 47/1000
# 930/930 [==============================] - 5s 5ms/step - loss: 1.1174 - accuracy: 0.4535 - val_loss: 1.1256 - val_accuracy: 0.4503
# Epoch 48/1000
# 930/930 [==============================] - 5s 6ms/step - loss: 1.1172 - accuracy: 0.4531 - val_loss: 1.1261 - val_accuracy: 0.4384
# Epoch 49/1000
# 930/930 [==============================] - 5s 6ms/step - loss: 1.1162 - accuracy: 0.4535 - val_loss: 1.1191 - val_accuracy: 0.4541
# Epoch 50/1000
# 930/930 [==============================] - 5s 6ms/step - loss: 1.1167 - accuracy: 0.4538 - val_loss: 1.1168 - val_accuracy: 0.4597
# Epoch 51/1000
# 930/930 [==============================] - 5s 6ms/step - loss: 1.1157 - accuracy: 0.4552 - val_loss: 1.1174 - val_accuracy: 0.4581
# Epoch 52/1000
# 930/930 [==============================] - 5s 5ms/step - loss: 1.1157 - accuracy: 0.4539 - val_loss: 1.1174 - val_accuracy: 0.4528
# Epoch 53/1000
# 930/930 [==============================] - 5s 6ms/step - loss: 1.1158 - accuracy: 0.4558 - val_loss: 1.1177 - val_accuracy: 0.4560
# Epoch 54/1000
# 930/930 [==============================] - 5s 6ms/step - loss: 1.1150 - accuracy: 0.4554 - val_loss: 1.1189 - val_accuracy: 0.4614
# Epoch 55/1000
# 930/930 [==============================] - 5s 6ms/step - loss: 1.1160 - accuracy: 0.4540 - val_loss: 1.1226 - val_accuracy: 0.4473
# Epoch 56/1000
# 930/930 [==============================] - 5s 5ms/step - loss: 1.1151 - accuracy: 0.4550 - val_loss: 1.1171 - val_accuracy: 0.4519
# Epoch 57/1000
# 930/930 [==============================] - 5s 6ms/step - loss: 1.1143 - accuracy: 0.4549 - val_loss: 1.1174 - val_accuracy: 0.4546
# Epoch 58/1000
# 930/930 [==============================] - 5s 5ms/step - loss: 1.1135 - accuracy: 0.4579 - val_loss: 1.1169 - val_accuracy: 0.4600
# Epoch 59/1000
# 930/930 [==============================] - 5s 6ms/step - loss: 1.1130 - accuracy: 0.4567 - val_loss: 1.1143 - val_accuracy: 0.4495
# Epoch 60/1000
# 930/930 [==============================] - 5s 6ms/step - loss: 1.1130 - accuracy: 0.4559 - val_loss: 1.1141 - val_accuracy: 0.4531
# Epoch 61/1000
# 930/930 [==============================] - 5s 6ms/step - loss: 1.1123 - accuracy: 0.4573 - val_loss: 1.1179 - val_accuracy: 0.4546
# Epoch 62/1000
# 930/930 [==============================] - 5s 6ms/step - loss: 1.1117 - accuracy: 0.4594 - val_loss: 1.1125 - val_accuracy: 0.4640
# Epoch 63/1000
# 930/930 [==============================] - 5s 6ms/step - loss: 1.1106 - accuracy: 0.4600 - val_loss: 1.1153 - val_accuracy: 0.4560
# Epoch 64/1000
# 930/930 [==============================] - 5s 5ms/step - loss: 1.1112 - accuracy: 0.4595 - val_loss: 1.1121 - val_accuracy: 0.4567
# Epoch 65/1000
# 930/930 [==============================] - 5s 5ms/step - loss: 1.1103 - accuracy: 0.4614 - val_loss: 1.1169 - val_accuracy: 0.4472
# Epoch 66/1000
# 930/930 [==============================] - 5s 6ms/step - loss: 1.1097 - accuracy: 0.4602 - val_loss: 1.1167 - val_accuracy: 0.4551
# Epoch 67/1000
# 930/930 [==============================] - 5s 5ms/step - loss: 1.1094 - accuracy: 0.4588 - val_loss: 1.1137 - val_accuracy: 0.4645
# Epoch 68/1000
# 930/930 [==============================] - 5s 6ms/step - loss: 1.1088 - accuracy: 0.4622 - val_loss: 1.1126 - val_accuracy: 0.4564
# Epoch 69/1000
# 930/930 [==============================] - 5s 5ms/step - loss: 1.1084 - accuracy: 0.4602 - val_loss: 1.1117 - val_accuracy: 0.4546
# Epoch 70/1000
# 930/930 [==============================] - 5s 6ms/step - loss: 1.1082 - accuracy: 0.4605 - val_loss: 1.1143 - val_accuracy: 0.4540
# Epoch 71/1000
# 930/930 [==============================] - 5s 6ms/step - loss: 1.1082 - accuracy: 0.4603 - val_loss: 1.1125 - val_accuracy: 0.4612
# Epoch 72/1000
# 930/930 [==============================] - 5s 6ms/step - loss: 1.1075 - accuracy: 0.4603 - val_loss: 1.1143 - val_accuracy: 0.4582
# Epoch 73/1000
# 930/930 [==============================] - 5s 6ms/step - loss: 1.1071 - accuracy: 0.4623 - val_loss: 1.1131 - val_accuracy: 0.4561
# Epoch 74/1000
# 930/930 [==============================] - 5s 6ms/step - loss: 1.1071 - accuracy: 0.4619 - val_loss: 1.1137 - val_accuracy: 0.4552
# Epoch 75/1000
# 930/930 [==============================] - 6s 6ms/step - loss: 1.1066 - accuracy: 0.4609 - val_loss: 1.1104 - val_accuracy: 0.4653
# Epoch 76/1000
# 930/930 [==============================] - 5s 6ms/step - loss: 1.1062 - accuracy: 0.4614 - val_loss: 1.1090 - val_accuracy: 0.4648
# Epoch 77/1000
# 930/930 [==============================] - 5s 6ms/step - loss: 1.1056 - accuracy: 0.4636 - val_loss: 1.1135 - val_accuracy: 0.4494
# Epoch 78/1000
# 930/930 [==============================] - 5s 6ms/step - loss: 1.1057 - accuracy: 0.4607 - val_loss: 1.1140 - val_accuracy: 0.4448
# Epoch 79/1000
# 930/930 [==============================] - 5s 6ms/step - loss: 1.1052 - accuracy: 0.4623 - val_loss: 1.1108 - val_accuracy: 0.4577
# Epoch 80/1000
# 930/930 [==============================] - 5s 6ms/step - loss: 1.1050 - accuracy: 0.4627 - val_loss: 1.1122 - val_accuracy: 0.4610
# Epoch 81/1000
# 930/930 [==============================] - 5s 6ms/step - loss: 1.1045 - accuracy: 0.4642 - val_loss: 1.1077 - val_accuracy: 0.4661
# Epoch 82/1000
# 930/930 [==============================] - 5s 6ms/step - loss: 1.1042 - accuracy: 0.4623 - val_loss: 1.1114 - val_accuracy: 0.4554
# Epoch 83/1000
# 930/930 [==============================] - 5s 6ms/step - loss: 1.1041 - accuracy: 0.4634 - val_loss: 1.1115 - val_accuracy: 0.4609
# Epoch 84/1000
# 930/930 [==============================] - 6s 6ms/step - loss: 1.1029 - accuracy: 0.4643 - val_loss: 1.1148 - val_accuracy: 0.4426
# Epoch 85/1000
# 930/930 [==============================] - 5s 6ms/step - loss: 1.1030 - accuracy: 0.4633 - val_loss: 1.1105 - val_accuracy: 0.4539
# Epoch 86/1000
# 930/930 [==============================] - 5s 6ms/step - loss: 1.1033 - accuracy: 0.4657 - val_loss: 1.1111 - val_accuracy: 0.4497
# Epoch 87/1000
# 930/930 [==============================] - 5s 6ms/step - loss: 1.1033 - accuracy: 0.4637 - val_loss: 1.1068 - val_accuracy: 0.4597
# Epoch 88/1000
# 930/930 [==============================] - 5s 6ms/step - loss: 1.1022 - accuracy: 0.4650 - val_loss: 1.1070 - val_accuracy: 0.4683
# Epoch 89/1000
# 930/930 [==============================] - 5s 6ms/step - loss: 1.1023 - accuracy: 0.4637 - val_loss: 1.1115 - val_accuracy: 0.4526
# Epoch 90/1000
# 930/930 [==============================] - 5s 6ms/step - loss: 1.1018 - accuracy: 0.4659 - val_loss: 1.1063 - val_accuracy: 0.4591
# Epoch 91/1000
# 930/930 [==============================] - 5s 6ms/step - loss: 1.1019 - accuracy: 0.4639 - val_loss: 1.1078 - val_accuracy: 0.4587
# Epoch 92/1000
# 930/930 [==============================] - 5s 5ms/step - loss: 1.1014 - accuracy: 0.4660 - val_loss: 1.1076 - val_accuracy: 0.4546
# Epoch 93/1000
# 930/930 [==============================] - 5s 6ms/step - loss: 1.1006 - accuracy: 0.4641 - val_loss: 1.1065 - val_accuracy: 0.4681
# Epoch 94/1000
# 930/930 [==============================] - 5s 6ms/step - loss: 1.1007 - accuracy: 0.4653 - val_loss: 1.1133 - val_accuracy: 0.4505
# Epoch 95/1000
# 930/930 [==============================] - 5s 6ms/step - loss: 1.1005 - accuracy: 0.4642 - val_loss: 1.1127 - val_accuracy: 0.4606
# Epoch 96/1000
# 930/930 [==============================] - 5s 6ms/step - loss: 1.1003 - accuracy: 0.4676 - val_loss: 1.1055 - val_accuracy: 0.4609
# Epoch 97/1000
# 930/930 [==============================] - 5s 6ms/step - loss: 1.1037 - accuracy: 0.4630 - val_loss: 1.1066 - val_accuracy: 0.4673
# Epoch 98/1000
# 930/930 [==============================] - 5s 6ms/step - loss: 1.1000 - accuracy: 0.4657 - val_loss: 1.1039 - val_accuracy: 0.4709
# Epoch 99/1000
# 930/930 [==============================] - 5s 6ms/step - loss: 1.0993 - accuracy: 0.4652 - val_loss: 1.1096 - val_accuracy: 0.4554
# Epoch 100/1000
# 930/930 [==============================] - 5s 5ms/step - loss: 1.0997 - accuracy: 0.4670 - val_loss: 1.1047 - val_accuracy: 0.4642
# Epoch 101/1000
# 930/930 [==============================] - 5s 6ms/step - loss: 1.0993 - accuracy: 0.4647 - val_loss: 1.1055 - val_accuracy: 0.4642
# Epoch 102/1000
# 930/930 [==============================] - 5s 5ms/step - loss: 1.0988 - accuracy: 0.4655 - val_loss: 1.1085 - val_accuracy: 0.4565
# Epoch 103/1000
# 930/930 [==============================] - 5s 6ms/step - loss: 1.0985 - accuracy: 0.4664 - val_loss: 1.1080 - val_accuracy: 0.4534
# Epoch 104/1000
# 930/930 [==============================] - 5s 6ms/step - loss: 1.0981 - accuracy: 0.4669 - val_loss: 1.1033 - val_accuracy: 0.4603
# Epoch 105/1000
# 930/930 [==============================] - 5s 6ms/step - loss: 1.0980 - accuracy: 0.4668 - val_loss: 1.1047 - val_accuracy: 0.4624
# Epoch 106/1000
# 930/930 [==============================] - 6s 6ms/step - loss: 1.0977 - accuracy: 0.4687 - val_loss: 1.1029 - val_accuracy: 0.4633
# Epoch 107/1000
# 930/930 [==============================] - 5s 6ms/step - loss: 1.0976 - accuracy: 0.4679 - val_loss: 1.1021 - val_accuracy: 0.4615
# Epoch 108/1000
# 930/930 [==============================] - 5s 6ms/step - loss: 1.0973 - accuracy: 0.4660 - val_loss: 1.1028 - val_accuracy: 0.4624
# Epoch 109/1000
# 930/930 [==============================] - 5s 6ms/step - loss: 1.1000 - accuracy: 0.4657 - val_loss: 1.1030 - val_accuracy: 0.4552
# Epoch 110/1000
# 930/930 [==============================] - 5s 6ms/step - loss: 1.0973 - accuracy: 0.4685 - val_loss: 1.1035 - val_accuracy: 0.4589
# Epoch 111/1000
# 930/930 [==============================] - 5s 6ms/step - loss: 1.0974 - accuracy: 0.4660 - val_loss: 1.1036 - val_accuracy: 0.4658
# Epoch 112/1000
# 930/930 [==============================] - 5s 6ms/step - loss: 1.1006 - accuracy: 0.4634 - val_loss: 1.1030 - val_accuracy: 0.4636
# Epoch 113/1000
# 930/930 [==============================] - 5s 6ms/step - loss: 1.0967 - accuracy: 0.4662 - val_loss: 1.1058 - val_accuracy: 0.4542
# Epoch 114/1000
# 930/930 [==============================] - 5s 6ms/step - loss: 1.0967 - accuracy: 0.4666 - val_loss: 1.1017 - val_accuracy: 0.4593
# Epoch 115/1000
# 930/930 [==============================] - 5s 6ms/step - loss: 1.0963 - accuracy: 0.4673 - val_loss: 1.1032 - val_accuracy: 0.4571
# Epoch 116/1000
# 930/930 [==============================] - 5s 6ms/step - loss: 1.0955 - accuracy: 0.4697 - val_loss: 1.1007 - val_accuracy: 0.4655
# Epoch 117/1000
# 930/930 [==============================] - 6s 6ms/step - loss: 1.0959 - accuracy: 0.4668 - val_loss: 1.0996 - val_accuracy: 0.4665
# Epoch 118/1000
# 930/930 [==============================] - 7s 7ms/step - loss: 1.0946 - accuracy: 0.4697 - val_loss: 1.1032 - val_accuracy: 0.4530
# Epoch 119/1000
# 930/930 [==============================] - 6s 6ms/step - loss: 1.0953 - accuracy: 0.4695 - val_loss: 1.1019 - val_accuracy: 0.4546
# Epoch 120/1000
# 930/930 [==============================] - 5s 6ms/step - loss: 1.0949 - accuracy: 0.4699 - val_loss: 1.1045 - val_accuracy: 0.4579
# Epoch 121/1000
# 930/930 [==============================] - 5s 6ms/step - loss: 1.0954 - accuracy: 0.4685 - val_loss: 1.1003 - val_accuracy: 0.4688
# Epoch 122/1000
# 930/930 [==============================] - 5s 6ms/step - loss: 1.0945 - accuracy: 0.4700 - val_loss: 1.1026 - val_accuracy: 0.4579
# Epoch 123/1000
# 930/930 [==============================] - 5s 6ms/step - loss: 1.0937 - accuracy: 0.4700 - val_loss: 1.1003 - val_accuracy: 0.4694
# Epoch 124/1000
# 930/930 [==============================] - 5s 6ms/step - loss: 1.0941 - accuracy: 0.4679 - val_loss: 1.0986 - val_accuracy: 0.4671
# Epoch 125/1000
# 930/930 [==============================] - 5s 6ms/step - loss: 1.0935 - accuracy: 0.4690 - val_loss: 1.1064 - val_accuracy: 0.4649
# Epoch 126/1000
# 930/930 [==============================] - 5s 6ms/step - loss: 1.0940 - accuracy: 0.4697 - val_loss: 1.1008 - val_accuracy: 0.4619
# Epoch 127/1000
# 930/930 [==============================] - 5s 6ms/step - loss: 1.0937 - accuracy: 0.4699 - val_loss: 1.0976 - val_accuracy: 0.4728
# Epoch 128/1000
# 930/930 [==============================] - 5s 6ms/step - loss: 1.0929 - accuracy: 0.4708 - val_loss: 1.1019 - val_accuracy: 0.4578
# Epoch 129/1000
# 930/930 [==============================] - 5s 6ms/step - loss: 1.0927 - accuracy: 0.4681 - val_loss: 1.0983 - val_accuracy: 0.4691
# Epoch 130/1000
# 930/930 [==============================] - 6s 6ms/step - loss: 1.0925 - accuracy: 0.4705 - val_loss: 1.0984 - val_accuracy: 0.4663
# Epoch 131/1000
# 930/930 [==============================] - 6s 6ms/step - loss: 1.0923 - accuracy: 0.4701 - val_loss: 1.1003 - val_accuracy: 0.4673
# Epoch 132/1000
# 930/930 [==============================] - 5s 6ms/step - loss: 1.0916 - accuracy: 0.4701 - val_loss: 1.0996 - val_accuracy: 0.4671
# Epoch 133/1000
# 930/930 [==============================] - 5s 6ms/step - loss: 1.0922 - accuracy: 0.4705 - val_loss: 1.0990 - val_accuracy: 0.4630
# Epoch 134/1000
# 930/930 [==============================] - 5s 6ms/step - loss: 1.0920 - accuracy: 0.4718 - val_loss: 1.1016 - val_accuracy: 0.4736
# Epoch 135/1000
# 930/930 [==============================] - 5s 6ms/step - loss: 1.0924 - accuracy: 0.4712 - val_loss: 1.0994 - val_accuracy: 0.4620
# Epoch 136/1000
# 930/930 [==============================] - 5s 6ms/step - loss: 1.0916 - accuracy: 0.4709 - val_loss: 1.0999 - val_accuracy: 0.4577
# Epoch 137/1000
# 930/930 [==============================] - 5s 6ms/step - loss: 1.0914 - accuracy: 0.4694 - val_loss: 1.0994 - val_accuracy: 0.4679
# Epoch 138/1000
# 930/930 [==============================] - 5s 6ms/step - loss: 1.0913 - accuracy: 0.4707 - val_loss: 1.0972 - val_accuracy: 0.4677
# Epoch 139/1000
# 930/930 [==============================] - 5s 6ms/step - loss: 1.0910 - accuracy: 0.4697 - val_loss: 1.1000 - val_accuracy: 0.4714
# Epoch 140/1000
# 930/930 [==============================] - 5s 6ms/step - loss: 1.0915 - accuracy: 0.4722 - val_loss: 1.0976 - val_accuracy: 0.4758
# Epoch 141/1000
# 930/930 [==============================] - 6s 6ms/step - loss: 1.0911 - accuracy: 0.4731 - val_loss: 1.0982 - val_accuracy: 0.4685
# Epoch 142/1000
# 930/930 [==============================] - 5s 6ms/step - loss: 1.0901 - accuracy: 0.4720 - val_loss: 1.0968 - val_accuracy: 0.4697
# Epoch 143/1000
# 930/930 [==============================] - 6s 6ms/step - loss: 1.0914 - accuracy: 0.4708 - val_loss: 1.0966 - val_accuracy: 0.4676
# Epoch 144/1000
# 930/930 [==============================] - 5s 6ms/step - loss: 1.0899 - accuracy: 0.4710 - val_loss: 1.0960 - val_accuracy: 0.4706
# Epoch 145/1000
# 930/930 [==============================] - 5s 6ms/step - loss: 1.0902 - accuracy: 0.4733 - val_loss: 1.0953 - val_accuracy: 0.4699
# Epoch 146/1000
# 930/930 [==============================] - 6s 6ms/step - loss: 1.0897 - accuracy: 0.4717 - val_loss: 1.0992 - val_accuracy: 0.4683
# Epoch 147/1000
# 930/930 [==============================] - 5s 6ms/step - loss: 1.0896 - accuracy: 0.4725 - val_loss: 1.0975 - val_accuracy: 0.4711
# Epoch 148/1000
# 930/930 [==============================] - 5s 6ms/step - loss: 1.0893 - accuracy: 0.4726 - val_loss: 1.0941 - val_accuracy: 0.4687
# Epoch 149/1000
# 930/930 [==============================] - 6s 6ms/step - loss: 1.0892 - accuracy: 0.4720 - val_loss: 1.0992 - val_accuracy: 0.4664
# Epoch 150/1000
# 930/930 [==============================] - 6s 7ms/step - loss: 1.0889 - accuracy: 0.4718 - val_loss: 1.0990 - val_accuracy: 0.4600
# Epoch 151/1000
# 930/930 [==============================] - 6s 7ms/step - loss: 1.0891 - accuracy: 0.4720 - val_loss: 1.0955 - val_accuracy: 0.4665
# Epoch 152/1000
# 930/930 [==============================] - 6s 6ms/step - loss: 1.0889 - accuracy: 0.4731 - val_loss: 1.0952 - val_accuracy: 0.4691
# Epoch 153/1000
# 930/930 [==============================] - 5s 6ms/step - loss: 1.0887 - accuracy: 0.4712 - val_loss: 1.0960 - val_accuracy: 0.4658
# Epoch 154/1000
# 930/930 [==============================] - 5s 5ms/step - loss: 1.0880 - accuracy: 0.4735 - val_loss: 1.0988 - val_accuracy: 0.4716
# Epoch 155/1000
# 930/930 [==============================] - 5s 5ms/step - loss: 1.0880 - accuracy: 0.4745 - val_loss: 1.0955 - val_accuracy: 0.4698
# Epoch 156/1000
# 930/930 [==============================] - 5s 6ms/step - loss: 1.0894 - accuracy: 0.4738 - val_loss: 1.1070 - val_accuracy: 0.4581
# Epoch 157/1000
# 930/930 [==============================] - 6s 6ms/step - loss: 1.0900 - accuracy: 0.4716 - val_loss: 1.0965 - val_accuracy: 0.4672
# Epoch 158/1000
# 930/930 [==============================] - 5s 6ms/step - loss: 1.0888 - accuracy: 0.4738 - val_loss: 1.0943 - val_accuracy: 0.4655
# Epoch 159/1000
# 930/930 [==============================] - 6s 6ms/step - loss: 1.0877 - accuracy: 0.4731 - val_loss: 1.0944 - val_accuracy: 0.4685
# Epoch 160/1000
# 930/930 [==============================] - 8s 9ms/step - loss: 1.0882 - accuracy: 0.4720 - val_loss: 1.0938 - val_accuracy: 0.4707
# Epoch 161/1000
# 930/930 [==============================] - 6s 6ms/step - loss: 1.0877 - accuracy: 0.4736 - val_loss: 1.0954 - val_accuracy: 0.4740
# Epoch 162/1000
# 930/930 [==============================] - 7s 7ms/step - loss: 1.0880 - accuracy: 0.4731 - val_loss: 1.0978 - val_accuracy: 0.4702
# Epoch 163/1000
# 930/930 [==============================] - 6s 7ms/step - loss: 1.0876 - accuracy: 0.4735 - val_loss: 1.0943 - val_accuracy: 0.4696
# Epoch 164/1000
# 930/930 [==============================] - 6s 7ms/step - loss: 1.0872 - accuracy: 0.4740 - val_loss: 1.0999 - val_accuracy: 0.4619
# Epoch 165/1000
# 930/930 [==============================] - 6s 6ms/step - loss: 1.0873 - accuracy: 0.4728 - val_loss: 1.0959 - val_accuracy: 0.4693
# Epoch 166/1000
# 930/930 [==============================] - 5s 6ms/step - loss: 1.0872 - accuracy: 0.4738 - val_loss: 1.0942 - val_accuracy: 0.4716
# Epoch 167/1000
# 930/930 [==============================] - 6s 6ms/step - loss: 1.0875 - accuracy: 0.4735 - val_loss: 1.0945 - val_accuracy: 0.4722
# Epoch 168/1000
# 930/930 [==============================] - 6s 7ms/step - loss: 1.0870 - accuracy: 0.4740 - val_loss: 1.0927 - val_accuracy: 0.4674
# Epoch 169/1000
# 930/930 [==============================] - 6s 7ms/step - loss: 1.0868 - accuracy: 0.4739 - val_loss: 1.0960 - val_accuracy: 0.4702
# Epoch 170/1000
# 930/930 [==============================] - 6s 6ms/step - loss: 1.0868 - accuracy: 0.4742 - val_loss: 1.0933 - val_accuracy: 0.4731
# Epoch 171/1000
# 930/930 [==============================] - 6s 6ms/step - loss: 1.0862 - accuracy: 0.4733 - val_loss: 1.0995 - val_accuracy: 0.4739
# Epoch 172/1000
# 930/930 [==============================] - 6s 7ms/step - loss: 1.0867 - accuracy: 0.4737 - val_loss: 1.0942 - val_accuracy: 0.4671
# Epoch 173/1000
# 930/930 [==============================] - 6s 6ms/step - loss: 1.0873 - accuracy: 0.4723 - val_loss: 1.0931 - val_accuracy: 0.4718
# Epoch 174/1000
# 930/930 [==============================] - 6s 6ms/step - loss: 1.0867 - accuracy: 0.4754 - val_loss: 1.0947 - val_accuracy: 0.4702
# Epoch 175/1000
# 930/930 [==============================] - 5s 6ms/step - loss: 1.0858 - accuracy: 0.4749 - val_loss: 1.0932 - val_accuracy: 0.4696
# Epoch 176/1000
# 930/930 [==============================] - 5s 6ms/step - loss: 1.0861 - accuracy: 0.4741 - val_loss: 1.0943 - val_accuracy: 0.4751
# Epoch 177/1000
# 930/930 [==============================] - 6s 6ms/step - loss: 1.0855 - accuracy: 0.4747 - val_loss: 1.0929 - val_accuracy: 0.4720
# Epoch 178/1000
# 930/930 [==============================] - 6s 6ms/step - loss: 1.0856 - accuracy: 0.4736 - val_loss: 1.0935 - val_accuracy: 0.4712
# Epoch 179/1000
# 930/930 [==============================] - 6s 7ms/step - loss: 1.0853 - accuracy: 0.4756 - val_loss: 1.0980 - val_accuracy: 0.4710
# Epoch 180/1000
# 930/930 [==============================] - 6s 7ms/step - loss: 1.0848 - accuracy: 0.4753 - val_loss: 1.0942 - val_accuracy: 0.4672
# Epoch 181/1000
# 930/930 [==============================] - 6s 6ms/step - loss: 1.0857 - accuracy: 0.4751 - val_loss: 1.0951 - val_accuracy: 0.4685
# Epoch 182/1000
# 930/930 [==============================] - 6s 6ms/step - loss: 1.0853 - accuracy: 0.4742 - val_loss: 1.0951 - val_accuracy: 0.4642
# Epoch 183/1000
# 930/930 [==============================] - 5s 6ms/step - loss: 1.0857 - accuracy: 0.4745 - val_loss: 1.0940 - val_accuracy: 0.4663
# Epoch 184/1000
# 930/930 [==============================] - 5s 6ms/step - loss: 1.0855 - accuracy: 0.4744 - val_loss: 1.0954 - val_accuracy: 0.4682
# Epoch 185/1000
# 930/930 [==============================] - 5s 6ms/step - loss: 1.0853 - accuracy: 0.4756 - val_loss: 1.0966 - val_accuracy: 0.4681
# Epoch 186/1000
# 930/930 [==============================] - 5s 6ms/step - loss: 1.0852 - accuracy: 0.4760 - val_loss: 1.0949 - val_accuracy: 0.4675
# Epoch 187/1000
# 930/930 [==============================] - 5s 6ms/step - loss: 1.0851 - accuracy: 0.4737 - val_loss: 1.0991 - val_accuracy: 0.4653
# Epoch 188/1000
# 930/930 [==============================] - 5s 6ms/step - loss: 1.0850 - accuracy: 0.4752 - val_loss: 1.0934 - val_accuracy: 0.4674
# Epoch 189/1000
# 930/930 [==============================] - 6s 6ms/step - loss: 1.0863 - accuracy: 0.4760 - val_loss: 1.1003 - val_accuracy: 0.4726
# Epoch 190/1000
# 930/930 [==============================] - 5s 5ms/step - loss: 1.0852 - accuracy: 0.4750 - val_loss: 1.0930 - val_accuracy: 0.4734
# Epoch 191/1000
# 930/930 [==============================] - 5s 5ms/step - loss: 1.0852 - accuracy: 0.4758 - val_loss: 1.0936 - val_accuracy: 0.4647
# Epoch 192/1000
# 930/930 [==============================] - 5s 6ms/step - loss: 1.0846 - accuracy: 0.4758 - val_loss: 1.1000 - val_accuracy: 0.4584
# Epoch 193/1000
# 930/930 [==============================] - 5s 6ms/step - loss: 1.0845 - accuracy: 0.4754 - val_loss: 1.0925 - val_accuracy: 0.4736
# Epoch 194/1000
# 930/930 [==============================] - 5s 6ms/step - loss: 1.0842 - accuracy: 0.4760 - val_loss: 1.0953 - val_accuracy: 0.4734
# Epoch 195/1000
# 930/930 [==============================] - 6s 6ms/step - loss: 1.0841 - accuracy: 0.4756 - val_loss: 1.0928 - val_accuracy: 0.4693
# Epoch 196/1000
# 930/930 [==============================] - 6s 6ms/step - loss: 1.0844 - accuracy: 0.4765 - val_loss: 1.0945 - val_accuracy: 0.4667
# Epoch 197/1000
# 930/930 [==============================] - 6s 6ms/step - loss: 1.0843 - accuracy: 0.4765 - val_loss: 1.0929 - val_accuracy: 0.4726
# Epoch 198/1000
# 930/930 [==============================] - 6s 6ms/step - loss: 1.0835 - accuracy: 0.4767 - val_loss: 1.0957 - val_accuracy: 0.4677
# Epoch 199/1000
# 930/930 [==============================] - 5s 6ms/step - loss: 1.0841 - accuracy: 0.4762 - val_loss: 1.0929 - val_accuracy: 0.4701
# Epoch 200/1000
# 930/930 [==============================] - 5s 6ms/step - loss: 1.0838 - accuracy: 0.4754 - val_loss: 1.0957 - val_accuracy: 0.4616
# Epoch 201/1000
# 930/930 [==============================] - 5s 6ms/step - loss: 1.0837 - accuracy: 0.4761 - val_loss: 1.0937 - val_accuracy: 0.4726
# Epoch 202/1000
# 930/930 [==============================] - 5s 6ms/step - loss: 1.0839 - accuracy: 0.4757 - val_loss: 1.0922 - val_accuracy: 0.4705
# Epoch 203/1000
# 930/930 [==============================] - 5s 6ms/step - loss: 1.0833 - accuracy: 0.4762 - val_loss: 1.0951 - val_accuracy: 0.4696
# Epoch 204/1000
# 930/930 [==============================] - 5s 6ms/step - loss: 1.0833 - accuracy: 0.4744 - val_loss: 1.0966 - val_accuracy: 0.4752
# Epoch 205/1000
# 930/930 [==============================] - 6s 6ms/step - loss: 1.0839 - accuracy: 0.4743 - val_loss: 1.0927 - val_accuracy: 0.4739
# Epoch 206/1000
# 930/930 [==============================] - 6s 6ms/step - loss: 1.0837 - accuracy: 0.4747 - val_loss: 1.0966 - val_accuracy: 0.4689
# Epoch 207/1000
# 930/930 [==============================] - 5s 6ms/step - loss: 1.0838 - accuracy: 0.4757 - val_loss: 1.0932 - val_accuracy: 0.4722
# Epoch 208/1000
# 930/930 [==============================] - 5s 6ms/step - loss: 1.0832 - accuracy: 0.4766 - val_loss: 1.0973 - val_accuracy: 0.4678
# Epoch 209/1000
# 930/930 [==============================] - 5s 5ms/step - loss: 1.0833 - accuracy: 0.4767 - val_loss: 1.0951 - val_accuracy: 0.4724
# Epoch 210/1000
# 930/930 [==============================] - 5s 6ms/step - loss: 1.0832 - accuracy: 0.4759 - val_loss: 1.0930 - val_accuracy: 0.4668
# Epoch 211/1000
# 930/930 [==============================] - 5s 6ms/step - loss: 1.0829 - accuracy: 0.4758 - val_loss: 1.0945 - val_accuracy: 0.4722
# Epoch 212/1000
# 930/930 [==============================] - 5s 6ms/step - loss: 1.0831 - accuracy: 0.4765 - val_loss: 1.0931 - val_accuracy: 0.4664
# Epoch 213/1000
# 930/930 [==============================] - 5s 6ms/step - loss: 1.0828 - accuracy: 0.4774 - val_loss: 1.0932 - val_accuracy: 0.4672
# Epoch 214/1000
# 930/930 [==============================] - 5s 6ms/step - loss: 1.0829 - accuracy: 0.4758 - val_loss: 1.0937 - val_accuracy: 0.4722
# Epoch 215/1000
# 930/930 [==============================] - 5s 6ms/step - loss: 1.0829 - accuracy: 0.4769 - val_loss: 1.0958 - val_accuracy: 0.4725
# Epoch 216/1000
# 930/930 [==============================] - 5s 6ms/step - loss: 1.0825 - accuracy: 0.4765 - val_loss: 1.0927 - val_accuracy: 0.4757
# Epoch 217/1000
# 930/930 [==============================] - 5s 6ms/step - loss: 1.0824 - accuracy: 0.4758 - val_loss: 1.0961 - val_accuracy: 0.4716
# Epoch 218/1000
# 930/930 [==============================] - 5s 6ms/step - loss: 1.0827 - accuracy: 0.4767 - val_loss: 1.0951 - val_accuracy: 0.4728
# Epoch 219/1000
# 930/930 [==============================] - 5s 6ms/step - loss: 1.0827 - accuracy: 0.4750 - val_loss: 1.0930 - val_accuracy: 0.4720
# Epoch 220/1000
# 930/930 [==============================] - 5s 6ms/step - loss: 1.0820 - accuracy: 0.4764 - val_loss: 1.0931 - val_accuracy: 0.4715
# Epoch 221/1000
# 930/930 [==============================] - 5s 6ms/step - loss: 1.0817 - accuracy: 0.4763 - val_loss: 1.0907 - val_accuracy: 0.4714
# Epoch 222/1000
# 930/930 [==============================] - 5s 6ms/step - loss: 1.0820 - accuracy: 0.4769 - val_loss: 1.0906 - val_accuracy: 0.4726
# Epoch 223/1000
# 930/930 [==============================] - 5s 6ms/step - loss: 1.0818 - accuracy: 0.4756 - val_loss: 1.1106 - val_accuracy: 0.4675
# Epoch 224/1000
# 930/930 [==============================] - 5s 6ms/step - loss: 1.0808 - accuracy: 0.4780 - val_loss: 1.0922 - val_accuracy: 0.4732
# Epoch 225/1000
# 930/930 [==============================] - 5s 6ms/step - loss: 1.0820 - accuracy: 0.4754 - val_loss: 1.0935 - val_accuracy: 0.4706
# Epoch 226/1000
# 930/930 [==============================] - 5s 6ms/step - loss: 1.0813 - accuracy: 0.4771 - val_loss: 1.0899 - val_accuracy: 0.4741
# Epoch 227/1000
# 930/930 [==============================] - 5s 6ms/step - loss: 1.0864 - accuracy: 0.4768 - val_loss: 1.0950 - val_accuracy: 0.4667
# Epoch 228/1000
# 930/930 [==============================] - 5s 6ms/step - loss: 1.0842 - accuracy: 0.4753 - val_loss: 1.0917 - val_accuracy: 0.4733
# Epoch 229/1000
# 930/930 [==============================] - 6s 6ms/step - loss: 1.0837 - accuracy: 0.4742 - val_loss: 1.0953 - val_accuracy: 0.4702
# Epoch 230/1000
# 930/930 [==============================] - 5s 6ms/step - loss: 1.0848 - accuracy: 0.4760 - val_loss: 1.0927 - val_accuracy: 0.4681
# Epoch 231/1000
# 930/930 [==============================] - 5s 6ms/step - loss: 1.0830 - accuracy: 0.4750 - val_loss: 1.0925 - val_accuracy: 0.4748
# Epoch 232/1000
# 930/930 [==============================] - 5s 6ms/step - loss: 1.0821 - accuracy: 0.4773 - val_loss: 1.0932 - val_accuracy: 0.4727
# Epoch 233/1000
# 930/930 [==============================] - 5s 6ms/step - loss: 1.0833 - accuracy: 0.4758 - val_loss: 1.0927 - val_accuracy: 0.4720
# Epoch 234/1000
# 930/930 [==============================] - 5s 6ms/step - loss: 1.0827 - accuracy: 0.4767 - val_loss: 1.0925 - val_accuracy: 0.4720
# Epoch 235/1000
# 930/930 [==============================] - 5s 6ms/step - loss: 1.0838 - accuracy: 0.4765 - val_loss: 1.0953 - val_accuracy: 0.4711
# Epoch 236/1000
# 930/930 [==============================] - 5s 6ms/step - loss: 1.0848 - accuracy: 0.4735 - val_loss: 1.0924 - val_accuracy: 0.4763
# Epoch 237/1000
# 930/930 [==============================] - 5s 6ms/step - loss: 1.0888 - accuracy: 0.4724 - val_loss: 1.1379 - val_accuracy: 0.4408
# Epoch 238/1000
# 930/930 [==============================] - 6s 6ms/step - loss: 1.0910 - accuracy: 0.4704 - val_loss: 1.0971 - val_accuracy: 0.4668
# Epoch 239/1000
# 930/930 [==============================] - 5s 6ms/step - loss: 1.0858 - accuracy: 0.4738 - val_loss: 1.0939 - val_accuracy: 0.4640
# Epoch 240/1000
# 930/930 [==============================] - 5s 6ms/step - loss: 1.0875 - accuracy: 0.4727 - val_loss: 1.0922 - val_accuracy: 0.4677
# Epoch 241/1000
# 930/930 [==============================] - 5s 6ms/step - loss: 1.0860 - accuracy: 0.4732 - val_loss: 1.0935 - val_accuracy: 0.4694
# Epoch 242/1000
# 930/930 [==============================] - 5s 6ms/step - loss: 1.0857 - accuracy: 0.4733 - val_loss: 1.0944 - val_accuracy: 0.4611
# Epoch 243/1000
# 930/930 [==============================] - 5s 6ms/step - loss: 1.0856 - accuracy: 0.4765 - val_loss: 1.0930 - val_accuracy: 0.4707
# Epoch 244/1000
# 930/930 [==============================] - 5s 6ms/step - loss: 1.0844 - accuracy: 0.4751 - val_loss: 1.0910 - val_accuracy: 0.4712
# Epoch 245/1000
# 930/930 [==============================] - 5s 6ms/step - loss: 1.0839 - accuracy: 0.4764 - val_loss: 1.0948 - val_accuracy: 0.4724
# Epoch 246/1000
# 930/930 [==============================] - 5s 6ms/step - loss: 1.0838 - accuracy: 0.4773 - val_loss: 1.0961 - val_accuracy: 0.4691
# Epoch 247/1000
# 930/930 [==============================] - 5s 6ms/step - loss: 1.0835 - accuracy: 0.4773 - val_loss: 1.0912 - val_accuracy: 0.4686
# Epoch 248/1000
# 930/930 [==============================] - 6s 6ms/step - loss: 1.0830 - accuracy: 0.4753 - val_loss: 1.0909 - val_accuracy: 0.4743
# Epoch 249/1000
# 930/930 [==============================] - 6s 6ms/step - loss: 1.0838 - accuracy: 0.4760 - val_loss: 1.0964 - val_accuracy: 0.4692
# Epoch 250/1000
# 930/930 [==============================] - 6s 6ms/step - loss: 1.0833 - accuracy: 0.4752 - val_loss: 1.0910 - val_accuracy: 0.4730
# Epoch 251/1000
# 930/930 [==============================] - 6s 6ms/step - loss: 1.0815 - accuracy: 0.4772 - val_loss: 1.0943 - val_accuracy: 0.4704
# Epoch 252/1000
# 930/930 [==============================] - 6s 7ms/step - loss: 1.0821 - accuracy: 0.4767 - val_loss: 1.0906 - val_accuracy: 0.4702
# Epoch 253/1000
# 930/930 [==============================] - 5s 6ms/step - loss: 1.0815 - accuracy: 0.4777 - val_loss: 1.0933 - val_accuracy: 0.4665
# Epoch 254/1000
# 930/930 [==============================] - 5s 6ms/step - loss: 1.0815 - accuracy: 0.4769 - val_loss: 1.0903 - val_accuracy: 0.4743
# Epoch 255/1000
# 930/930 [==============================] - 6s 6ms/step - loss: 1.0819 - accuracy: 0.4764 - val_loss: 1.0932 - val_accuracy: 0.4704
# Epoch 256/1000
# 930/930 [==============================] - 5s 6ms/step - loss: 1.0818 - accuracy: 0.4777 - val_loss: 1.0860 - val_accuracy: 0.4726
# Epoch 257/1000
# 930/930 [==============================] - 5s 6ms/step - loss: 1.0810 - accuracy: 0.4778 - val_loss: 1.0954 - val_accuracy: 0.4613
# Epoch 258/1000
# 930/930 [==============================] - 6s 6ms/step - loss: 1.0801 - accuracy: 0.4781 - val_loss: 1.0985 - val_accuracy: 0.4661
# Epoch 259/1000
# 930/930 [==============================] - 5s 6ms/step - loss: 1.0793 - accuracy: 0.4768 - val_loss: 1.0895 - val_accuracy: 0.4728
# Epoch 260/1000
# 930/930 [==============================] - 5s 6ms/step - loss: 1.0771 - accuracy: 0.4781 - val_loss: 1.0913 - val_accuracy: 0.4695
# Epoch 261/1000
# 930/930 [==============================] - 5s 6ms/step - loss: 1.0814 - accuracy: 0.4777 - val_loss: 1.0912 - val_accuracy: 0.4700
# Epoch 262/1000
# 930/930 [==============================] - 5s 6ms/step - loss: 1.0787 - accuracy: 0.4774 - val_loss: 1.0930 - val_accuracy: 0.4637
# Epoch 263/1000
# 930/930 [==============================] - 5s 6ms/step - loss: 1.0800 - accuracy: 0.4780 - val_loss: 1.0999 - val_accuracy: 0.4744
# Epoch 264/1000
# 930/930 [==============================] - 5s 6ms/step - loss: 1.0814 - accuracy: 0.4770 - val_loss: 1.0948 - val_accuracy: 0.4725
# Epoch 265/1000
# 930/930 [==============================] - 6s 6ms/step - loss: 1.0807 - accuracy: 0.4773 - val_loss: 1.0901 - val_accuracy: 0.4741
# Epoch 266/1000
# 930/930 [==============================] - 5s 6ms/step - loss: 1.0799 - accuracy: 0.4767 - val_loss: 1.0934 - val_accuracy: 0.4645
# Epoch 267/1000
# 930/930 [==============================] - 5s 6ms/step - loss: 1.0790 - accuracy: 0.4773 - val_loss: 1.0875 - val_accuracy: 0.4723
# Epoch 268/1000
# 930/930 [==============================] - 5s 6ms/step - loss: 1.0885 - accuracy: 0.4727 - val_loss: 1.0927 - val_accuracy: 0.4659
# Epoch 269/1000
# 930/930 [==============================] - 5s 6ms/step - loss: 1.0905 - accuracy: 0.4726 - val_loss: 1.0933 - val_accuracy: 0.4623
# Epoch 270/1000
# 930/930 [==============================] - 5s 6ms/step - loss: 1.0856 - accuracy: 0.4740 - val_loss: 1.0916 - val_accuracy: 0.4671
# Epoch 271/1000
# 930/930 [==============================] - 5s 6ms/step - loss: 1.0848 - accuracy: 0.4750 - val_loss: 1.0956 - val_accuracy: 0.4791
# Epoch 272/1000
# 930/930 [==============================] - 6s 6ms/step - loss: 1.0845 - accuracy: 0.4753 - val_loss: 1.0947 - val_accuracy: 0.4753
# Epoch 273/1000
# 930/930 [==============================] - 5s 6ms/step - loss: 1.0843 - accuracy: 0.4746 - val_loss: 1.0921 - val_accuracy: 0.4696
# Epoch 274/1000
# 930/930 [==============================] - 5s 6ms/step - loss: 1.0845 - accuracy: 0.4735 - val_loss: 1.0936 - val_accuracy: 0.4720
# Epoch 275/1000
# 930/930 [==============================] - 5s 6ms/step - loss: 1.0851 - accuracy: 0.4751 - val_loss: 1.0946 - val_accuracy: 0.4700
# Epoch 276/1000
# 930/930 [==============================] - 6s 6ms/step - loss: 1.0840 - accuracy: 0.4764 - val_loss: 1.0942 - val_accuracy: 0.4738
# Epoch 277/1000
# 930/930 [==============================] - 6s 6ms/step - loss: 1.0852 - accuracy: 0.4759 - val_loss: 1.0908 - val_accuracy: 0.4743
# Epoch 278/1000
# 930/930 [==============================] - 5s 6ms/step - loss: 1.0858 - accuracy: 0.4745 - val_loss: 1.0935 - val_accuracy: 0.4676
# Epoch 279/1000
# 930/930 [==============================] - 5s 6ms/step - loss: 1.0848 - accuracy: 0.4733 - val_loss: 1.0967 - val_accuracy: 0.4791
# Epoch 280/1000
# 930/930 [==============================] - 6s 6ms/step - loss: 1.0858 - accuracy: 0.4739 - val_loss: 1.0935 - val_accuracy: 0.4714
# Epoch 281/1000
# 930/930 [==============================] - 5s 6ms/step - loss: 1.0836 - accuracy: 0.4763 - val_loss: 1.0926 - val_accuracy: 0.4650
# Epoch 282/1000
# 930/930 [==============================] - 5s 6ms/step - loss: 1.0842 - accuracy: 0.4766 - val_loss: 1.0909 - val_accuracy: 0.4728
# Epoch 283/1000
# 930/930 [==============================] - 6s 6ms/step - loss: 1.0841 - accuracy: 0.4760 - val_loss: 1.0912 - val_accuracy: 0.4723
# Epoch 284/1000
# 930/930 [==============================] - 5s 6ms/step - loss: 1.0836 - accuracy: 0.4773 - val_loss: 1.0926 - val_accuracy: 0.4655
# Epoch 285/1000
# 930/930 [==============================] - 5s 6ms/step - loss: 1.0839 - accuracy: 0.4767 - val_loss: 1.0900 - val_accuracy: 0.4727
# Epoch 286/1000
# 930/930 [==============================] - 5s 6ms/step - loss: 1.0833 - accuracy: 0.4773 - val_loss: 1.0957 - val_accuracy: 0.4628
# Epoch 287/1000
# 930/930 [==============================] - 5s 6ms/step - loss: 1.0851 - accuracy: 0.4756 - val_loss: 1.0933 - val_accuracy: 0.4641
# Epoch 288/1000
# 930/930 [==============================] - 5s 6ms/step - loss: 1.0844 - accuracy: 0.4754 - val_loss: 1.0936 - val_accuracy: 0.4614
# Epoch 289/1000
# 930/930 [==============================] - 5s 6ms/step - loss: 1.0834 - accuracy: 0.4762 - val_loss: 1.0955 - val_accuracy: 0.4732
# Epoch 290/1000
# 930/930 [==============================] - 5s 6ms/step - loss: 1.0832 - accuracy: 0.4767 - val_loss: 1.0953 - val_accuracy: 0.4703
# Epoch 291/1000
# 930/930 [==============================] - 5s 6ms/step - loss: 1.0861 - accuracy: 0.4736 - val_loss: 1.1032 - val_accuracy: 0.4647
# Epoch 292/1000
# 930/930 [==============================] - 6s 6ms/step - loss: 1.0852 - accuracy: 0.4742 - val_loss: 1.0929 - val_accuracy: 0.4682
# Epoch 293/1000
# 930/930 [==============================] - 5s 6ms/step - loss: 1.0840 - accuracy: 0.4755 - val_loss: 1.0964 - val_accuracy: 0.4681
# Epoch 294/1000
# 930/930 [==============================] - 6s 6ms/step - loss: 1.0851 - accuracy: 0.4753 - val_loss: 1.0937 - val_accuracy: 0.4700
# Epoch 295/1000
# 930/930 [==============================] - 5s 6ms/step - loss: 1.0825 - accuracy: 0.4774 - val_loss: 1.0944 - val_accuracy: 0.4739
# Epoch 296/1000
# 930/930 [==============================] - 5s 6ms/step - loss: 1.0873 - accuracy: 0.4743 - val_loss: 1.0995 - val_accuracy: 0.4647
# Epoch 297/1000
# 930/930 [==============================] - 5s 6ms/step - loss: 1.0849 - accuracy: 0.4732 - val_loss: 1.0948 - val_accuracy: 0.4687
# Epoch 298/1000
# 930/930 [==============================] - 5s 6ms/step - loss: 1.0857 - accuracy: 0.4763 - val_loss: 1.0911 - val_accuracy: 0.4709
# Epoch 299/1000
# 930/930 [==============================] - 5s 6ms/step - loss: 1.0842 - accuracy: 0.4760 - val_loss: 1.0902 - val_accuracy: 0.4712
# Epoch 300/1000
# 930/930 [==============================] - 5s 6ms/step - loss: 1.0841 - accuracy: 0.4740 - val_loss: 1.0927 - val_accuracy: 0.4655
# Epoch 301/1000
# 930/930 [==============================] - 5s 6ms/step - loss: 1.0836 - accuracy: 0.4771 - val_loss: 1.0908 - val_accuracy: 0.4688
# Epoch 302/1000
# 930/930 [==============================] - 5s 6ms/step - loss: 1.0837 - accuracy: 0.4756 - val_loss: 1.0899 - val_accuracy: 0.4723
# Epoch 303/1000
# 930/930 [==============================] - 5s 6ms/step - loss: 1.0827 - accuracy: 0.4767 - val_loss: 1.0914 - val_accuracy: 0.4692
# Epoch 304/1000
# 930/930 [==============================] - 5s 6ms/step - loss: 1.0823 - accuracy: 0.4767 - val_loss: 1.0913 - val_accuracy: 0.4713
# Epoch 305/1000
# 930/930 [==============================] - 5s 6ms/step - loss: 1.0862 - accuracy: 0.4757 - val_loss: 1.0915 - val_accuracy: 0.4649
# Epoch 306/1000
# 930/930 [==============================] - 5s 6ms/step - loss: 1.0855 - accuracy: 0.4744 - val_loss: 1.0909 - val_accuracy: 0.4749
# Epoch 307/1000
# 930/930 [==============================] - 5s 6ms/step - loss: 1.0838 - accuracy: 0.4771 - val_loss: 1.0914 - val_accuracy: 0.4763
# Epoch 308/1000
# 930/930 [==============================] - 5s 6ms/step - loss: 1.0832 - accuracy: 0.4767 - val_loss: 1.0947 - val_accuracy: 0.4763
# Epoch 309/1000
# 930/930 [==============================] - 6s 6ms/step - loss: 1.0841 - accuracy: 0.4765 - val_loss: 1.0921 - val_accuracy: 0.4669
# Epoch 310/1000
# 930/930 [==============================] - 5s 6ms/step - loss: 1.0840 - accuracy: 0.4767 - val_loss: 1.0919 - val_accuracy: 0.4696
# Epoch 311/1000
# 930/930 [==============================] - 5s 6ms/step - loss: 1.0829 - accuracy: 0.4752 - val_loss: 1.0915 - val_accuracy: 0.4656
# Epoch 312/1000
# 930/930 [==============================] - 5s 6ms/step - loss: 1.0831 - accuracy: 0.4756 - val_loss: 1.0914 - val_accuracy: 0.4720
# Epoch 313/1000
# 930/930 [==============================] - 5s 6ms/step - loss: 1.0834 - accuracy: 0.4754 - val_loss: 1.0921 - val_accuracy: 0.4724
# Epoch 314/1000
# 930/930 [==============================] - 5s 6ms/step - loss: 1.0839 - accuracy: 0.4770 - val_loss: 1.0926 - val_accuracy: 0.4710
# Epoch 315/1000
# 930/930 [==============================] - 6s 6ms/step - loss: 1.0831 - accuracy: 0.4744 - val_loss: 1.0954 - val_accuracy: 0.4771
# Epoch 316/1000
# 930/930 [==============================] - 6s 6ms/step - loss: 1.0828 - accuracy: 0.4755 - val_loss: 1.0899 - val_accuracy: 0.4710
# Epoch 317/1000
# 930/930 [==============================] - 6s 6ms/step - loss: 1.0823 - accuracy: 0.4766 - val_loss: 1.0912 - val_accuracy: 0.4735
# Epoch 318/1000
# 930/930 [==============================] - 5s 6ms/step - loss: 1.0826 - accuracy: 0.4764 - val_loss: 1.0926 - val_accuracy: 0.4741
# Epoch 319/1000
# 930/930 [==============================] - 5s 6ms/step - loss: 1.0840 - accuracy: 0.4749 - val_loss: 1.0938 - val_accuracy: 0.4735
# Epoch 320/1000
# 930/930 [==============================] - 5s 6ms/step - loss: 1.0831 - accuracy: 0.4747 - val_loss: 1.0905 - val_accuracy: 0.4663
# Epoch 321/1000
# 930/930 [==============================] - 5s 6ms/step - loss: 1.0834 - accuracy: 0.4741 - val_loss: 1.0905 - val_accuracy: 0.4761
# Epoch 322/1000
# 930/930 [==============================] - 5s 6ms/step - loss: 1.0833 - accuracy: 0.4757 - val_loss: 1.0915 - val_accuracy: 0.4715
# Epoch 323/1000
# 930/930 [==============================] - 5s 6ms/step - loss: 1.0828 - accuracy: 0.4768 - val_loss: 1.0909 - val_accuracy: 0.4693
# Epoch 324/1000
# 930/930 [==============================] - 5s 6ms/step - loss: 1.0820 - accuracy: 0.4777 - val_loss: 1.0916 - val_accuracy: 0.4747
# Epoch 325/1000
# 930/930 [==============================] - 5s 6ms/step - loss: 1.0816 - accuracy: 0.4777 - val_loss: 1.0923 - val_accuracy: 0.4714
# Epoch 326/1000
# 930/930 [==============================] - 5s 6ms/step - loss: 1.0827 - accuracy: 0.4769 - val_loss: 1.0922 - val_accuracy: 0.4698
# Epoch 327/1000
# 930/930 [==============================] - 5s 6ms/step - loss: 1.0830 - accuracy: 0.4760 - val_loss: 1.0920 - val_accuracy: 0.4684
# Epoch 328/1000
# 930/930 [==============================] - 6s 6ms/step - loss: 1.0829 - accuracy: 0.4751 - val_loss: 1.0917 - val_accuracy: 0.4743
# Epoch 329/1000
# 930/930 [==============================] - 5s 6ms/step - loss: 1.0823 - accuracy: 0.4774 - val_loss: 1.0926 - val_accuracy: 0.4706
# Epoch 330/1000
# ...
# Epoch 892/1000
# 930/930 [==============================] - 6s 6ms/step - loss: 1.0712 - accuracy: 0.4845 - val_loss: 1.0846 - val_accuracy: 0.4776
# Epoch 893/1000
# 930/930 [==============================] - 6s 6ms/step - loss: 1.0712 - accuracy: 0.4836 - val_loss: 1.0851 - val_accuracy: 0.4748
# Epoch 894/1000
# 930/930 [==============================] - 6s 6ms/step - loss: 1.0718 - accuracy: 0.4834 - val_loss: 1.0870 - val_accuracy: 0.4717
# Epoch 895/1000
# 930/930 [==============================] - 6s 6ms/step - loss: 1.0713 - accuracy: 0.4843 - val_loss: 1.0859 - val_accuracy: 0.4757
# Epoch 896/1000
# 930/930 [==============================] - 6s 6ms/step - loss: 1.0724 - accuracy: 0.4826 - val_loss: 1.0829 - val_accuracy: 0.4755
# Epoch 897/1000
# 930/930 [==============================] - 6s 6ms/step - loss: 1.0713 - accuracy: 0.4833 - val_loss: 1.0841 - val_accuracy: 0.4787
# Epoch 898/1000
# 930/930 [==============================] - 6s 7ms/step - loss: 1.0720 - accuracy: 0.4840 - val_loss: 1.0858 - val_accuracy: 0.4791
# Epoch 899/1000
# 930/930 [==============================] - 6s 6ms/step - loss: 1.0714 - accuracy: 0.4834 - val_loss: 1.0859 - val_accuracy: 0.4748
# Epoch 900/1000
# 930/930 [==============================] - 6s 6ms/step - loss: 1.0715 - accuracy: 0.4836 - val_loss: 1.0854 - val_accuracy: 0.4767
# Epoch 901/1000
# 930/930 [==============================] - 5s 6ms/step - loss: 1.0717 - accuracy: 0.4837 - val_loss: 1.0834 - val_accuracy: 0.4815
# Epoch 902/1000
# 930/930 [==============================] - 6s 6ms/step - loss: 1.0715 - accuracy: 0.4821 - val_loss: 1.0817 - val_accuracy: 0.4759
# Epoch 903/1000
# 930/930 [==============================] - 5s 6ms/step - loss: 1.0717 - accuracy: 0.4830 - val_loss: 1.0846 - val_accuracy: 0.4794
# Epoch 904/1000
# 930/930 [==============================] - 6s 6ms/step - loss: 1.0716 - accuracy: 0.4850 - val_loss: 1.0890 - val_accuracy: 0.4712
# Epoch 905/1000
# 930/930 [==============================] - 6s 6ms/step - loss: 1.0715 - accuracy: 0.4807 - val_loss: 1.0840 - val_accuracy: 0.4811
# Epoch 906/1000
# 930/930 [==============================] - 5s 6ms/step - loss: 1.0715 - accuracy: 0.4831 - val_loss: 1.0846 - val_accuracy: 0.4776
# Epoch 907/1000
# 930/930 [==============================] - 5s 6ms/step - loss: 1.0712 - accuracy: 0.4831 - val_loss: 1.0869 - val_accuracy: 0.4742
# Epoch 908/1000
# 930/930 [==============================] - 6s 6ms/step - loss: 1.0716 - accuracy: 0.4836 - val_loss: 1.0856 - val_accuracy: 0.4793
# Epoch 909/1000
# 930/930 [==============================] - 5s 6ms/step - loss: 1.0713 - accuracy: 0.4845 - val_loss: 1.0853 - val_accuracy: 0.4777
# Epoch 910/1000
# 930/930 [==============================] - 6s 6ms/step - loss: 1.0711 - accuracy: 0.4847 - val_loss: 1.0837 - val_accuracy: 0.4796
# Epoch 911/1000
# 930/930 [==============================] - 5s 6ms/step - loss: 1.0712 - accuracy: 0.4829 - val_loss: 1.0836 - val_accuracy: 0.4772
# Epoch 912/1000
# 930/930 [==============================] - 6s 6ms/step - loss: 1.0712 - accuracy: 0.4840 - val_loss: 1.0832 - val_accuracy: 0.4747
# Epoch 913/1000
# 930/930 [==============================] - 6s 6ms/step - loss: 1.0716 - accuracy: 0.4838 - val_loss: 1.0832 - val_accuracy: 0.4766
# Epoch 914/1000
# 930/930 [==============================] - 6s 6ms/step - loss: 1.0711 - accuracy: 0.4835 - val_loss: 1.0858 - val_accuracy: 0.4790
# Epoch 915/1000
# 930/930 [==============================] - 5s 6ms/step - loss: 1.0711 - accuracy: 0.4827 - val_loss: 1.0833 - val_accuracy: 0.4726
# Epoch 916/1000
# 930/930 [==============================] - 6s 6ms/step - loss: 1.0713 - accuracy: 0.4841 - val_loss: 1.0837 - val_accuracy: 0.4786
# Epoch 917/1000
# 930/930 [==============================] - 6s 6ms/step - loss: 1.0715 - accuracy: 0.4834 - val_loss: 1.0835 - val_accuracy: 0.4770
# Epoch 918/1000
# 930/930 [==============================] - 6s 6ms/step - loss: 1.0710 - accuracy: 0.4828 - val_loss: 1.0850 - val_accuracy: 0.4806
# Epoch 919/1000
# 930/930 [==============================] - 6s 6ms/step - loss: 1.0711 - accuracy: 0.4846 - val_loss: 1.0872 - val_accuracy: 0.4741
# Epoch 920/1000
# 930/930 [==============================] - 6s 6ms/step - loss: 1.0712 - accuracy: 0.4832 - val_loss: 1.0829 - val_accuracy: 0.4776
# Epoch 921/1000
# 930/930 [==============================] - 5s 6ms/step - loss: 1.0714 - accuracy: 0.4833 - val_loss: 1.0852 - val_accuracy: 0.4821
# Epoch 922/1000
# 930/930 [==============================] - 5s 5ms/step - loss: 1.0709 - accuracy: 0.4837 - val_loss: 1.0849 - val_accuracy: 0.4750
# Epoch 923/1000
# 930/930 [==============================] - 5s 6ms/step - loss: 1.0714 - accuracy: 0.4830 - val_loss: 1.0876 - val_accuracy: 0.4786
# Epoch 924/1000
# 930/930 [==============================] - 5s 6ms/step - loss: 1.0712 - accuracy: 0.4847 - val_loss: 1.0844 - val_accuracy: 0.4806
# Epoch 925/1000
# 930/930 [==============================] - 5s 6ms/step - loss: 1.0716 - accuracy: 0.4812 - val_loss: 1.0834 - val_accuracy: 0.4788
# Epoch 926/1000
# 930/930 [==============================] - 5s 6ms/step - loss: 1.0713 - accuracy: 0.4820 - val_loss: 1.0829 - val_accuracy: 0.4790
# Epoch 927/1000
# 930/930 [==============================] - 5s 6ms/step - loss: 1.0714 - accuracy: 0.4848 - val_loss: 1.0822 - val_accuracy: 0.4773
# Epoch 928/1000
# 930/930 [==============================] - 5s 5ms/step - loss: 1.0709 - accuracy: 0.4832 - val_loss: 1.0818 - val_accuracy: 0.4789
# Epoch 929/1000
# 930/930 [==============================] - 5s 5ms/step - loss: 1.0708 - accuracy: 0.4836 - val_loss: 1.0835 - val_accuracy: 0.4803
# Epoch 930/1000
# 930/930 [==============================] - 5s 6ms/step - loss: 1.0706 - accuracy: 0.4840 - val_loss: 1.0840 - val_accuracy: 0.4784
# Epoch 931/1000
# 930/930 [==============================] - 5s 6ms/step - loss: 1.0712 - accuracy: 0.4819 - val_loss: 1.0816 - val_accuracy: 0.4799
# Epoch 932/1000
# 930/930 [==============================] - 5s 5ms/step - loss: 1.0708 - accuracy: 0.4845 - val_loss: 1.0831 - val_accuracy: 0.4839
# Epoch 933/1000
# 930/930 [==============================] - 5s 6ms/step - loss: 1.0709 - accuracy: 0.4842 - val_loss: 1.0821 - val_accuracy: 0.4819
# Epoch 934/1000
# 930/930 [==============================] - 5s 6ms/step - loss: 1.0709 - accuracy: 0.4823 - val_loss: 1.0828 - val_accuracy: 0.4794
# Epoch 935/1000
# 930/930 [==============================] - 5s 6ms/step - loss: 1.0703 - accuracy: 0.4848 - val_loss: 1.0860 - val_accuracy: 0.4808
# Epoch 936/1000
# 930/930 [==============================] - 5s 6ms/step - loss: 1.0703 - accuracy: 0.4843 - val_loss: 1.0840 - val_accuracy: 0.4748
# Epoch 937/1000
# 930/930 [==============================] - 5s 5ms/step - loss: 1.0699 - accuracy: 0.4858 - val_loss: 1.0855 - val_accuracy: 0.4768
# Epoch 938/1000
# 930/930 [==============================] - 5s 5ms/step - loss: 1.0702 - accuracy: 0.4831 - val_loss: 1.0834 - val_accuracy: 0.4804
# Epoch 939/1000
# 930/930 [==============================] - 5s 6ms/step - loss: 1.0705 - accuracy: 0.4848 - val_loss: 1.0844 - val_accuracy: 0.4795
# Epoch 940/1000
# 930/930 [==============================] - 5s 6ms/step - loss: 1.0699 - accuracy: 0.4844 - val_loss: 1.0842 - val_accuracy: 0.4772
# Epoch 941/1000
# 930/930 [==============================] - 5s 5ms/step - loss: 1.0695 - accuracy: 0.4857 - val_loss: 1.0849 - val_accuracy: 0.4743
# Epoch 942/1000
# 930/930 [==============================] - 5s 6ms/step - loss: 1.0698 - accuracy: 0.4847 - val_loss: 1.0813 - val_accuracy: 0.4815
# Epoch 943/1000
# 930/930 [==============================] - 5s 6ms/step - loss: 1.0709 - accuracy: 0.4843 - val_loss: 1.0838 - val_accuracy: 0.4742
# Epoch 944/1000
# 930/930 [==============================] - 5s 6ms/step - loss: 1.0703 - accuracy: 0.4842 - val_loss: 1.0824 - val_accuracy: 0.4769
# Epoch 945/1000
# 930/930 [==============================] - 5s 5ms/step - loss: 1.0695 - accuracy: 0.4861 - val_loss: 1.0817 - val_accuracy: 0.4819
# Epoch 946/1000
# 930/930 [==============================] - 5s 6ms/step - loss: 1.0695 - accuracy: 0.4854 - val_loss: 1.0826 - val_accuracy: 0.4780
# Epoch 947/1000
# 930/930 [==============================] - 5s 6ms/step - loss: 1.0696 - accuracy: 0.4845 - val_loss: 1.0839 - val_accuracy: 0.4743
# Epoch 948/1000
# 930/930 [==============================] - 5s 5ms/step - loss: 1.0700 - accuracy: 0.4847 - val_loss: 1.0833 - val_accuracy: 0.4803
# Epoch 949/1000
# 930/930 [==============================] - 5s 6ms/step - loss: 1.0690 - accuracy: 0.4842 - val_loss: 1.0824 - val_accuracy: 0.4790
# Epoch 950/1000
# 930/930 [==============================] - 5s 6ms/step - loss: 1.0690 - accuracy: 0.4845 - val_loss: 1.0819 - val_accuracy: 0.4798
# Epoch 951/1000
# 930/930 [==============================] - 5s 5ms/step - loss: 1.0693 - accuracy: 0.4860 - val_loss: 1.0850 - val_accuracy: 0.4769
# Epoch 952/1000
# 930/930 [==============================] - 5s 5ms/step - loss: 1.0691 - accuracy: 0.4841 - val_loss: 1.0821 - val_accuracy: 0.4770
# Epoch 953/1000
# 930/930 [==============================] - 5s 6ms/step - loss: 1.0686 - accuracy: 0.4835 - val_loss: 1.0840 - val_accuracy: 0.4741
# Epoch 954/1000
# 930/930 [==============================] - 5s 5ms/step - loss: 1.0683 - accuracy: 0.4840 - val_loss: 1.0804 - val_accuracy: 0.4827
# Epoch 955/1000
# 930/930 [==============================] - 5s 6ms/step - loss: 1.0682 - accuracy: 0.4862 - val_loss: 1.0840 - val_accuracy: 0.4815
# Epoch 956/1000
# 930/930 [==============================] - 5s 6ms/step - loss: 1.0681 - accuracy: 0.4856 - val_loss: 1.0813 - val_accuracy: 0.4765
# Epoch 957/1000
# 930/930 [==============================] - 5s 5ms/step - loss: 1.0682 - accuracy: 0.4852 - val_loss: 1.0841 - val_accuracy: 0.4792
# Epoch 958/1000
# 930/930 [==============================] - 5s 5ms/step - loss: 1.0680 - accuracy: 0.4852 - val_loss: 1.0812 - val_accuracy: 0.4795
# Epoch 959/1000
# 930/930 [==============================] - 5s 5ms/step - loss: 1.0679 - accuracy: 0.4843 - val_loss: 1.0864 - val_accuracy: 0.4724
# Epoch 960/1000
# 930/930 [==============================] - 5s 5ms/step - loss: 1.0681 - accuracy: 0.4848 - val_loss: 1.0836 - val_accuracy: 0.4776
# Epoch 961/1000
# 930/930 [==============================] - 5s 5ms/step - loss: 1.0674 - accuracy: 0.4851 - val_loss: 1.0812 - val_accuracy: 0.4806
# Epoch 962/1000
# 930/930 [==============================] - 5s 6ms/step - loss: 1.0676 - accuracy: 0.4854 - val_loss: 1.0879 - val_accuracy: 0.4667
# Epoch 963/1000
# 930/930 [==============================] - 5s 5ms/step - loss: 1.0681 - accuracy: 0.4843 - val_loss: 1.0799 - val_accuracy: 0.4787
# Epoch 964/1000
# 930/930 [==============================] - 5s 5ms/step - loss: 1.0669 - accuracy: 0.4854 - val_loss: 1.0820 - val_accuracy: 0.4785
# Epoch 965/1000
# 930/930 [==============================] - 5s 6ms/step - loss: 1.0704 - accuracy: 0.4833 - val_loss: 1.0838 - val_accuracy: 0.4734
# Epoch 966/1000
# 930/930 [==============================] - 5s 5ms/step - loss: 1.0709 - accuracy: 0.4815 - val_loss: 1.0845 - val_accuracy: 0.4761
# Epoch 967/1000
# 930/930 [==============================] - 5s 5ms/step - loss: 1.0709 - accuracy: 0.4839 - val_loss: 1.0845 - val_accuracy: 0.4829
# Epoch 968/1000
# 930/930 [==============================] - 5s 6ms/step - loss: 1.0703 - accuracy: 0.4853 - val_loss: 1.0823 - val_accuracy: 0.4783
# Epoch 969/1000
# 930/930 [==============================] - 5s 6ms/step - loss: 1.0698 - accuracy: 0.4831 - val_loss: 1.0820 - val_accuracy: 0.4792
# Epoch 970/1000
# 930/930 [==============================] - 5s 5ms/step - loss: 1.0713 - accuracy: 0.4846 - val_loss: 1.0837 - val_accuracy: 0.4768
# Epoch 971/1000
# 930/930 [==============================] - 5s 5ms/step - loss: 1.0712 - accuracy: 0.4836 - val_loss: 1.0844 - val_accuracy: 0.4797
# Epoch 972/1000
# 930/930 [==============================] - 5s 6ms/step - loss: 1.0710 - accuracy: 0.4837 - val_loss: 1.0842 - val_accuracy: 0.4775
# Epoch 973/1000
# 930/930 [==============================] - 5s 6ms/step - loss: 1.0719 - accuracy: 0.4842 - val_loss: 1.0853 - val_accuracy: 0.4775
# Epoch 974/1000
# 930/930 [==============================] - 5s 5ms/step - loss: 1.0712 - accuracy: 0.4836 - val_loss: 1.0850 - val_accuracy: 0.4812
# Epoch 975/1000
# 930/930 [==============================] - 5s 5ms/step - loss: 1.0715 - accuracy: 0.4840 - val_loss: 1.0846 - val_accuracy: 0.4772
# Epoch 976/1000
# 930/930 [==============================] - 5s 6ms/step - loss: 1.0710 - accuracy: 0.4834 - val_loss: 1.0872 - val_accuracy: 0.4757
# Epoch 977/1000
# 930/930 [==============================] - 5s 6ms/step - loss: 1.0709 - accuracy: 0.4827 - val_loss: 1.0848 - val_accuracy: 0.4740
# Epoch 978/1000
# 930/930 [==============================] - 5s 5ms/step - loss: 1.0711 - accuracy: 0.4844 - val_loss: 1.0844 - val_accuracy: 0.4769
# Epoch 979/1000
# 930/930 [==============================] - 5s 6ms/step - loss: 1.0709 - accuracy: 0.4850 - val_loss: 1.0829 - val_accuracy: 0.4798
# Epoch 980/1000
# 930/930 [==============================] - 5s 5ms/step - loss: 1.0709 - accuracy: 0.4836 - val_loss: 1.0828 - val_accuracy: 0.4800
# Epoch 981/1000
# 930/930 [==============================] - 5s 5ms/step - loss: 1.0709 - accuracy: 0.4838 - val_loss: 1.0843 - val_accuracy: 0.4805
# Epoch 982/1000
# 930/930 [==============================] - 5s 6ms/step - loss: 1.0708 - accuracy: 0.4850 - val_loss: 1.0845 - val_accuracy: 0.4736
# Epoch 983/1000
# 930/930 [==============================] - 5s 5ms/step - loss: 1.0719 - accuracy: 0.4808 - val_loss: 1.0843 - val_accuracy: 0.4783
# Epoch 984/1000
# 930/930 [==============================] - 5s 6ms/step - loss: 1.0709 - accuracy: 0.4846 - val_loss: 1.0837 - val_accuracy: 0.4801
# Epoch 985/1000
# 930/930 [==============================] - 5s 5ms/step - loss: 1.0706 - accuracy: 0.4829 - val_loss: 1.0854 - val_accuracy: 0.4767
# Epoch 986/1000
# 930/930 [==============================] - 5s 5ms/step - loss: 1.0707 - accuracy: 0.4847 - val_loss: 1.0854 - val_accuracy: 0.4763
# Epoch 987/1000
# 930/930 [==============================] - 5s 6ms/step - loss: 1.0734 - accuracy: 0.4830 - val_loss: 1.0837 - val_accuracy: 0.4767
# Epoch 988/1000
# 930/930 [==============================] - 5s 5ms/step - loss: 1.0710 - accuracy: 0.4845 - val_loss: 1.0851 - val_accuracy: 0.4784
# Epoch 989/1000
# 930/930 [==============================] - 5s 5ms/step - loss: 1.0710 - accuracy: 0.4831 - val_loss: 1.0837 - val_accuracy: 0.4786
# Epoch 990/1000
# 930/930 [==============================] - 5s 6ms/step - loss: 1.0712 - accuracy: 0.4840 - val_loss: 1.0873 - val_accuracy: 0.4781
# Epoch 991/1000
# 930/930 [==============================] - 5s 6ms/step - loss: 1.0712 - accuracy: 0.4835 - val_loss: 1.0852 - val_accuracy: 0.4793
# Epoch 992/1000
# 930/930 [==============================] - 5s 6ms/step - loss: 1.0709 - accuracy: 0.4843 - val_loss: 1.0840 - val_accuracy: 0.4788
# Epoch 993/1000
# 930/930 [==============================] - 5s 6ms/step - loss: 1.0715 - accuracy: 0.4821 - val_loss: 1.0842 - val_accuracy: 0.4794
# Epoch 994/1000
# 930/930 [==============================] - 5s 6ms/step - loss: 1.0709 - accuracy: 0.4832 - val_loss: 1.0840 - val_accuracy: 0.4788
# Epoch 995/1000
# 930/930 [==============================] - 5s 5ms/step - loss: 1.0714 - accuracy: 0.4830 - val_loss: 1.0863 - val_accuracy: 0.4808
# Epoch 996/1000
# 930/930 [==============================] - 5s 5ms/step - loss: 1.0705 - accuracy: 0.4840 - val_loss: 1.0832 - val_accuracy: 0.4806
# Epoch 997/1000
# 930/930 [==============================] - 5s 6ms/step - loss: 1.0714 - accuracy: 0.4841 - val_loss: 1.0850 - val_accuracy: 0.4796
# Epoch 998/1000
# 930/930 [==============================] - 5s 5ms/step - loss: 1.0707 - accuracy: 0.4838 - val_loss: 1.0821 - val_accuracy: 0.4766
# Epoch 999/1000
# 930/930 [==============================] - 5s 6ms/step - loss: 1.0709 - accuracy: 0.4827 - val_loss: 1.0822 - val_accuracy: 0.4776
# Epoch 1000/1000
# 930/930 [==============================] - 5s 6ms/step - loss: 1.0698 - accuracy: 0.4837 - val_loss: 1.0839 - val_accuracy: 0.4780

# %%
# Ambil histori akurasi dan loss dari proses pelatihan
train_accuracy = history.history['accuracy']
test_accuracy = history.history['val_accuracy']
train_loss = history.history['loss']
test_loss = history.history['val_loss']

# Buat plot untuk akurasi
plt.figure(figsize=(8, 6))
plt.plot(range(1, len(train_accuracy) + 1), train_accuracy, label='Training Accuracy')
plt.plot(range(1, len(test_accuracy) + 1), test_accuracy, label='Test Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title('Training and Test Accuracy')
plt.legend()
plt.show()

# Buat plot untuk loss
plt.figure(figsize=(8, 6))
plt.plot(range(1, len(train_loss) + 1), train_loss, label='Training Loss')
plt.plot(range(1, len(test_loss) + 1), test_loss, label='Test Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training and Test Loss')
plt.legend()
plt.show()

# %%
# Evaluasi performa pada data latih
training_scores = model.evaluate(X_train, y_train)
print("Performa pada Data Latih:")
print("Loss:", training_scores[0])
print("Akurasi:", training_scores[1])
# Out:
# 1860/1860 [==============================] - 5s 3ms/step - loss: 1.0702 - accuracy: 0.4859
# Performa pada Data Latih:
# Loss: 1.0701982975006104
# Akurasi: 0.4859206974506378

# %%
# Evaluasi performa pada data uji
loss, accuracy = model.evaluate(X_test, y_test)
print("Loss pada Data Uji:", loss)
print("Akurasi pada Data Uji:", accuracy)
# Out:
# 465/465 [==============================] - 1s 3ms/step - loss: 1.0839 - accuracy: 0.4780
# Loss pada Data Uji: 1.0838860273361206
# Akurasi pada Data Uji: 0.47795698046684265

# %%
# Menghitung prediksi pada data uji
y_test_pred = model.predict(X_test)
# Out:
# 465/465 [==============================] - 2s 2ms/step

# %%
from sklearn.metrics import classification_report, confusion_matrix, mean_squared_error, mean_absolute_error

# metrik evaluasi untuk masalah regresi
print("Mean Squared Error:")
print(mean_squared_error(y_test, y_test_pred))

print("Mean Absolute Error:")
print(mean_absolute_error(y_test, y_test_pred))
# Out:
# Mean Squared Error:
# 0.15045133
# Mean Absolute Error:
# 0.29949903

# %%
model.save('All.h5')

# %% [markdown]
# ## Load Model

# %%
model = load_model('All.h5')

# %% [markdown]
# # Predict Datates

# %%
# Membaca dataset yang ingin diprediksi
predict_df = pd.read_csv('C:/Users/Afif Alaudin/Documents/GitHub/ta2023-boneusg/Data 6 Juli - Fix/LTSM/Process/50%/K502_processed.csv')
X_predict = predict_df.iloc[:].values

# %%
# Memprediksi label menggunakan model yang telah dilatih
y_pred_encoded = model.predict(X_predict)
y_pred = np.argmax(y_pred_encoded, axis=1)
y_pred_label = label_encoder.inverse_transform(y_pred)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\Users\Afif Alaudin\Documents\GitHub\ta2023-boneusg\Data 6 Juli - Fix\LTSM\LTSM_Full.ipynb Cell 37 in 2
#       <a href='vscode-notebook-cell:/c%3A/Users/Afif%20Alaudin/Documents/GitHub/ta2023-boneusg/Data%206%20Juli%20-%20Fix/LTSM/LTSM_Full.ipynb#X43sZmlsZQ%3D%3D?line=0'>1</a> # Memprediksi label menggunakan model yang telah dilatih
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Afif%20Alaudin/Documents/GitHub/ta2023-boneusg/Data%206%20Juli%20-%20Fix/LTSM/LTSM_Full.ipynb#X43sZmlsZQ%3D%3D?line=1'>2</a> y_pred_encoded = model.predict(X_predict)
#       <a href='vscode-notebook-cell:/c%3A/Users/Afif%20Alaudin/Documents/GitHub/ta2023-boneusg/Data%206%20Juli%20-%20Fix/LTSM/LTSM_Full.ipynb#X43sZmlsZQ%3D%3D?line=2'>3</a> y_pred = np.argmax(y_pred_encoded, axis=1)
#       <a href='vscode-notebook-cell:/c%3A/Users/Afif%20Alaudin/Documents/GitHub/ta2023-boneusg/Data%206%20Juli%20-%20Fix/LTSM/LTSM_Full.ipynb#X43sZmlsZQ%3D%3D?line=3'>4</a> y_pred_label = label_encoder.inverse_transform(y_pred)
#
# File c:\Users\Afif Alaudin\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\utils\traceback_utils.py:70, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#      68     # To get the full stack trace, call:
#      69     # `tf.debugging.disable_traceback_filtering()`
# ---> 70     raise e.with_traceback(filtered_tb) from None
#      71 finally:
#      72     del filtered_tb
#
# File C:\Users\AFIFAL~1\AppData\Local\Temp\__autograph_generated_filezrr_vy6y.py:15, in outer_factory.<locals>.inner_factory.<locals>.tf__predict_function(iterator)
#      13 try:
#      14     do_return = True
# ---> 15     retval_ = ag__.converted_call(ag__.ld(step_function), (ag__.ld(self), ag__.ld(iterator)), None, fscope)
#      16 except:
#      17     do_return = False
#
# ValueError: in user code:
#
#     File "c:\Users\Afif Alaudin\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\engine\training.py", line 2169, in predict_function  *
#         return step_function(self, iterator)
#     File "c:\Users\Afif Alaudin\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\engine\training.py", line 2155, in step_function  **
#         outputs = model.distribute_strategy.run(run_step, args=(data,))
#     File "c:\Users\Afif Alaudin\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\engine\training.py", line 2143, in run_step  **
#         outputs = model.predict_step(data)
#     File "c:\Users\Afif Alaudin\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\engine\training.py", line 2111, in predict_step
#         return self(x, training=False)
#     File "c:\Users\Afif Alaudin\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\utils\traceback_utils.py", line 70, in error_handler
#         raise e.with_traceback(filtered_tb) from None
#     File "c:\Users\Afif Alaudin\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\engine\input_spec.py", line 298, in assert_input_compatibility
#         raise ValueError(
#
#     ValueError: Input 0 of layer "sequential_5" is incompatible with the layer: expected shape=(None, 3, 1), found shape=(None, 2)

# %% [markdown]
# # Save Predict

# %%
result_df = predict_df.copy()
result_df['predicted_label'] = y_pred_label
result_df.to_csv('data_predict_predicted.csv', index=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\Afif Alaudin\Documents\GitHub\ta2023-boneusg\Data 6 Juli - Fix\LTSM\LTSM_Full.ipynb Cell 40 in 2
#       <a href='vscode-notebook-cell:/c%3A/Users/Afif%20Alaudin/Documents/GitHub/ta2023-boneusg/Data%206%20Juli%20-%20Fix/LTSM/LTSM_Full.ipynb#X45sZmlsZQ%3D%3D?line=0'>1</a> result_df = predict_df.copy()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Afif%20Alaudin/Documents/GitHub/ta2023-boneusg/Data%206%20Juli%20-%20Fix/LTSM/LTSM_Full.ipynb#X45sZmlsZQ%3D%3D?line=1'>2</a> result_df['predicted_label'] = y_pred_label
#       <a href='vscode-notebook-cell:/c%3A/Users/Afif%20Alaudin/Documents/GitHub/ta2023-boneusg/Data%206%20Juli%20-%20Fix/LTSM/LTSM_Full.ipynb#X45sZmlsZQ%3D%3D?line=2'>3</a> result_df.to_csv('data_predict_predicted.csv', index=False)
#
# NameError: name 'y_pred_label' is not defined

# %% [markdown]
# # Result Predict

# %%
print(result_df['predicted_label'].value_counts())

# %%
# Membandingkan kemiripan label dengan dataset utama

similar_labels = []
for label in result_df['predicted_label'].unique():
    similarity = max(SequenceMatcher(None, label, unique_label).ratio() for unique_label in np.unique(y))
if similarity > 0.7:
    print("Data match :", label)

# %%
Piye carane ben iso muncul 1 dataset tok
