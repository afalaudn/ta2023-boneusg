# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %% [markdown]
# # Plot PSD Regresi Linear

# %%
X = np.array([0.002781, 0.001452, 0.000674, 0.003219]).reshape(-1, 1)
Y = np.array([30, 50, 70, 90])

# %%
model = LinearRegression()

# %%
model.fit(X, Y)
# Out:
# LinearRegression()

# %%
koefisien_kemiringan = model.coef_[0]
konstanta = model.intercept_

# %%
print("Koefisien Kemiringan: ", koefisien_kemiringan)
print("Konstanta: ", konstanta)
# Out:
# Koefisien Kemiringan:  1291.4004056828362
# Konstanta:  57.37652007585532

# %%
Y_prediksi = model.predict(X)

# %%
plt.scatter(X, Y, label='Data')
plt.plot(X, Y_prediksi, color='red', label='Regresi Linear')
plt.xlabel('Nilai Puncak Rata-rata')
plt.ylabel('Densitas Model Tulang')
plt.legend()
plt.grid(True)
plt.title("REGRESI LINEAR RATA-RATA PUNCAK PSD SISI ATAS")
plt.show()

# %% [markdown]
# ## Sisi Samping

# %%
X = np.array([0.032401, 0.008570, 0.004040, 0.07041]).reshape(-1, 1)
Y = np.array([30, 50, 70, 90])

# %%
model = LinearRegression()

# %%
model.fit(X, Y)
# Out:
# LinearRegression()

# %%
koefisien_kemiringan = model.coef_[0]
konstanta = model.intercept_

# %%
print("Koefisien Kemiringan: ", koefisien_kemiringan)
print("Konstanta: ", konstanta)
# Out:
# Koefisien Kemiringan:  395.7735874728066
# Konstanta:  48.579854190075295

# %%
Y_prediksi = model.predict(X)

# %%
plt.scatter(X, Y, label='Data')
plt.plot(X, Y_prediksi, color='red', label='Regresi Linear')
plt.xlabel('Nilai Puncak Rata-rata')
plt.ylabel('Densitas Model Tulang')
plt.legend()
plt.grid(True)
plt.title("REGRESI LINEAR RATA-RATA PUNCAK RAW DATA SISI SAMPING")
plt.show()

# %% [markdown]
# ## Sisi Kecil

# %%
X = np.array([0.044861, 0.010857, 0.023149, 0.005385]).reshape(-1, 1)
Y = np.array([30, 50, 70, 90])

# %%
model = LinearRegression()

# %%
model.fit(X, Y)
# Out:
# LinearRegression()

# %%
koefisien_kemiringan = model.coef_[0]
konstanta = model.intercept_

# %%
print("Koefisien Kemiringan: ", koefisien_kemiringan)
print("Konstanta: ", konstanta)
# Out:
# Koefisien Kemiringan:  -1152.8272508306882
# Konstanta:  84.28200038424679

# %%
Y_prediksi = model.predict(X)

# %%
plt.scatter(X, Y, label='Data')
plt.plot(X, Y_prediksi, color='red', label='Regresi Linear')
plt.xlabel('Nilai Puncak Rata-rata')
plt.ylabel('Densitas Model Tulang')
plt.legend()
plt.grid(True)
plt.title("REGRESI LINEAR NILAI RATA-RATA PUNCAK PSD SISI KECIL")
plt.show()

# %% [markdown]
# # Plot FFT Regresi Linear

# %% [markdown]
# ### Atas

# %%
X = np.array([0.021450, 0.016459, 0.012637, 0.024804]).reshape(-1, 1)
Y = np.array([30, 50, 70, 90])

# %%
model = LinearRegression()

# %%
model.fit(X, Y)
# Out:
# LinearRegression()

# %%
koefisien_kemiringan = model.coef_[0]
konstanta = model.intercept_

# %%
print("Koefisien Kemiringan: ", koefisien_kemiringan)
print("Konstanta: ", konstanta)
# Out:
# Koefisien Kemiringan:  721.1560047545911
# Konstanta:  46.41522376043539

# %%
Y_prediksi = model.predict(X)

# %%
plt.scatter(X, Y, label='Data')
plt.plot(X, Y_prediksi, color='red', label='Regresi Linear')
plt.xlabel('Nilai Puncak Rata-rata')
plt.ylabel('Densitas Model Tulang')
plt.legend()
plt.grid(True)
plt.title("REGRESI LINEAR NILAI RATA-RATA PUNCAK FFT SISI ATAS")
plt.show()

# %% [markdown]
# ### Samping

# %%
X = np.array([0.077214, 0.043999, 0.031274, 0.040459]).reshape(-1, 1)
Y = np.array([30, 50, 70, 90])

# %%
model = LinearRegression()

# %%
model.fit(X, Y)
# Out:
# LinearRegression()

# %%
koefisien_kemiringan = model.coef_[0]
konstanta = model.intercept_

# %%
print("Koefisien Kemiringan: ", koefisien_kemiringan)
print("Konstanta: ", konstanta)
# Out:
# Koefisien Kemiringan:  -1019.9293608318975
# Konstanta:  109.19782261376783

# %%
Y_prediksi = model.predict(X)

# %%
plt.scatter(X, Y, label='Data')
plt.plot(X, Y_prediksi, color='red', label='Regresi Linear')
plt.xlabel('Nilai Puncak Rata-rata')
plt.ylabel('Densitas Model Tulang')
plt.legend()
plt.grid(True)
plt.title("REGRESI LINEAR NILAI RATA-RATA PUNCAK FFT SISI SAMPING")
plt.show()

# %% [markdown]
# ### Kecil

# %%
X = np.array([0.091208, 0.050160, 0.055994, 0.035707]).reshape(-1, 1)
Y = np.array([30, 50, 70, 90])

# %%
model = LinearRegression()

# %%
model.fit(X, Y)
# Out:
# LinearRegression()

# %%
koefisien_kemiringan = model.coef_[0]
konstanta = model.intercept_

# %%
print("Koefisien Kemiringan: ", koefisien_kemiringan)
print("Konstanta: ", konstanta)
# Out:
# Koefisien Kemiringan:  -965.0061853433023
# Konstanta:  116.22825665294452

# %%
Y_prediksi = model.predict(X)

# %%
plt.scatter(X, Y, label='Data')
plt.plot(X, Y_prediksi, color='red', label='Regresi Linear')
plt.xlabel('Nilai Puncak Rata-rata')
plt.ylabel('Densitas Model Tulang')
plt.legend()
plt.grid(True)
plt.title("REGRESI LINEAR NILAI RATA-RATA PUNCAK FFT SISI KECIL")
plt.show()

# %% [markdown]
# # Plot FFT Regresi Polinomial

# %%
# PLOT NILAI FFT PUNCAK SISI ATAS
X = np.array([0.021450, 0.016459, 0.012637, 0.024804])
Y = np.array([30, 50, 70, 90])

# Membuat model regresi polinomial (contoh menggunakan polinomial derajat 2)
coefficients = np.polyfit(X, Y, 2)
a_2 = coefficients[0]
a_1 = coefficients[1]
a_0 = coefficients[2]

# Membuat persamaan regresi polinomial
regression_line = np.poly1d(coefficients)

# Plot data dan regresi polinomial
plt.scatter(X, Y, label='Data')
plt.plot(X, regression_line(X), color='red', label='Regresi Polinomial')
plt.xlabel('Densitas Model Tulang')
plt.ylabel('Nilai Puncak Rata-rata')
plt.title("REGRESI POLINOMIAL NILAI RATA-RATA PUNCAK FFT SISI ATAS")
plt.legend()
plt.grid(True)
plt.show()

# %%
# PLOT NILAI FFT PUNCAK SISI SAMPING
X = np.array([0.077214, 0.043999, 0.031274, 0.040459])
Y = np.array([30, 50, 70, 90])

# Membuat model regresi polinomial (contoh menggunakan polinomial derajat 2)
coefficients = np.polyfit(X, Y, 2)
a_2 = coefficients[0]
a_1 = coefficients[1]
a_0 = coefficients[2]

# Membuat persamaan regresi polinomial
regression_line = np.poly1d(coefficients)

# Plot data dan regresi polinomial
plt.scatter(X, Y, label='Data')
plt.plot(X, regression_line(X), color='red', label='Regresi Polinomial')
plt.xlabel('Densitas Model Tulang')
plt.ylabel('Nilai Puncak Rata-rata')
plt.title("REGRESI POLINOMIAL NILAI RATA-RATA PUNCAK FFT SISI SAMPING")
plt.legend()
plt.grid(True)
plt.show()

# %%
# PLOT NILAI FFT PUNCAK SISI KECIL
X = np.array([0.091208, 0.050160, 0.055994, 0.035707])
Y = np.array([30, 50, 70, 90])

# Membuat model regresi polinomial (contoh menggunakan polinomial derajat 2)
coefficients = np.polyfit(X, Y, 2)
a_2 = coefficients[0]
a_1 = coefficients[1]
a_0 = coefficients[2]

# Membuat persamaan regresi polinomial
regression_line = np.poly1d(coefficients)

# Plot data dan regresi polinomial
plt.scatter(X, Y, label='Data')
plt.plot(X, regression_line(X), color='red', label='Regresi Polinomial')
plt.xlabel('Densitas Model Tulang')
plt.ylabel('Nilai Puncak Rata-rata')
plt.title("REGRESI POLINOMIAL NILAI RATA-RATA PUNCAK FFT SISI KECIL")
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# # Plot PSD Regresi Polinomial

# %%
# PLOT NILAI PSD PUNCAK SISI ATAS
X = np.array([0.002781, 0.001452, 0.000674, 0.003219])
Y = np.array([30, 50, 70, 90])

# Membuat model regresi polinomial (contoh menggunakan polinomial derajat 2)
coefficients = np.polyfit(X, Y, 2)
a_2 = coefficients[0]
a_1 = coefficients[1]
a_0 = coefficients[2]

# Membuat persamaan regresi polinomial
regression_line = np.poly1d(coefficients)

# Plot data dan regresi polinomial
plt.scatter(X, Y, label='Data')
plt.plot(X, regression_line(X), color='red', label='Regresi Polinomial')
plt.xlabel('Densitas Model Tulang')
plt.ylabel('Nilai Puncak Rata-rata')
plt.title("REGRESI POLINOMIAL NILAI RATA-RATA PUNCAK PSD SISI ATAS")
plt.legend()
plt.grid(True)
plt.show()

# %%
# PLOT NILAI PSD PUNCAK SISI SAMPING
X = np.array([0.032401, 0.008570, 0.004040, 0.07041])
Y = np.array([30, 50, 70, 90])

# Membuat model regresi polinomial (contoh menggunakan polinomial derajat 2)
coefficients = np.polyfit(X, Y, 2)
a_2 = coefficients[0]
a_1 = coefficients[1]
a_0 = coefficients[2]

# Membuat persamaan regresi polinomial
regression_line = np.poly1d(coefficients)

# Plot data dan regresi polinomial
plt.scatter(X, Y, label='Data')
plt.plot(X, regression_line(X), color='red', label='Regresi Polinomial')
plt.xlabel('Densitas Model Tulang')
plt.ylabel('Nilai Puncak Rata-rata')
plt.title("REGRESI POLINOMIAL NILAI RATA-RATA PUNCAK PSD SISI SAMPING")
plt.legend()
plt.grid(True)
plt.show()

# %%
# PLOT NILAI PSD PUNCAK SISI KECIL
X = np.array([0.044861, 0.010857, 0.023149, 0.005385])
Y = np.array([30, 50, 70, 90])

# Membuat model regresi polinomial (contoh menggunakan polinomial derajat 2)
coefficients = np.polyfit(X, Y, 2)
a_2 = coefficients[0]
a_1 = coefficients[1]
a_0 = coefficients[2]

# Membuat persamaan regresi polinomial
regression_line = np.poly1d(coefficients)

# Plot data dan regresi polinomial
plt.scatter(X, Y, label='Data')
plt.plot(X, regression_line(X), color='red', label='Regresi Polinomial')
plt.xlabel('Densitas Model Tulang')
plt.ylabel('Nilai Puncak Rata-rata')
plt.title("REGRESI POLINOMIAL NILAI RATA-RATA PUNCAK PSD SISI KECIL")
plt.legend()
plt.grid(True)
plt.show()
